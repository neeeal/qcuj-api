# %%
import os
from flask import Flask, request, jsonify
from flask_cors import CORS 
# import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import nltk
import pymysql
import numpy as np
import datetime

from dotenv import load_dotenv

# %%
app = Flask(__name__)
app.json.sort_keys = False
CORS(app) 

db = pymysql.connect(
    host=os.getenv('DATABASE_HOST'),
    user=os.getenv('DATABASE_USER'),
    password=os.getenv('DATABASE_PASSWORD'),
    db=os.getenv('DATABASE_DB'),
    connect_timeout=8800,
    cursorclass=pymysql.cursors.DictCursor
)

# %% [markdown]
# ## Authors

# %%
# sql_query= """
#             SELECT * FROM contributors 
#            """
sql_query= """
            SELECT * FROM author 
           """

# %%
db.ping(reconnect=True)
cursor = db.cursor()
cursor.execute(sql_query)
data = cursor.fetchall()

# %%
data
# Out:
# [{'author_id': 1,
#   'journal_id': 1,
#   'first_name': 'QCU',
#   'last_name': 'Journal',
#   'middle_name': '',
#   'public_name': None,
#   'email': 'qcujournalexample@gmail.com',
#   'email_verified': 'qcujournalexample@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': '',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': None,
#   'position': 'FACULTY',
#   'country': None,
#   'school_name': '',
#   'field_of_expertise': '',
#   'bio': None,
#   'orc_id': '',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 1, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None},
#  {'author_id': 159,
#   'journal_id': None,
#   'first_name': 'Eloisa Marie',
#   'last_name': 'Baylon',
#   'middle_name': 'Maglana',
#   'public_name': None,
#   'email': 'eloisamariebaylon@gmail.com',
#   'email_verified': 'eloisamariebaylon@gmail.com',
#   'password': 'dc59ff69ba37853ebe3cd04c30db24dc6a55344fa1665317c4413587248222b1',
#   'gender': 'Female',
#   'birth_date': datetime.date(1948, 1, 7),
#   'phone_number': '+639551626672',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'Web Development',
#   'bio': '',
#   'orc_id': '0009-0003-9088-8268',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 2, 22, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/423539900_355183254071354_4981676414683112915_n.jpg'},
#  {'author_id': 160,
#   'journal_id': None,
#   'first_name': 'Mon Cedric',
#   'last_name': 'Avila',
#   'middle_name': 'Orbeta',
#   'public_name': None,
#   'email': 'avilamon0123@gmail.com',
#   'email_verified': 'avilamon0123@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': 'Male',
#   'birth_date': datetime.date(2001, 11, 24),
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'Web Development',
#   'bio': '',
#   'orc_id': '0009-0005-4489-9198',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 2, 22, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': '../Files/uploaded-profile/Avila, Mon Cedric O..jpg'},
#  {'author_id': 161,
#   'journal_id': None,
#   'first_name': 'Mavis',
#   'last_name': 'Vermillion',
#   'middle_name': 'Teach',
#   'public_name': None,
#   'email': 'jhexphel16@gmail.com',
#   'email_verified': 'jhexphel16@gmail.com',
#   'password': 'd07e7c4cce2afb5fdab874b1f6c1f95a06564921bad3486805e5bd27fad62457',
#   'gender': 'Male',
#   'birth_date': datetime.date(2002, 4, 25),
#   'phone_number': '',
#   'afiliations': 'College of Cooking Pansit Canton',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Web Development',
#   'bio': '“‘Move on.’ Anim na letrang salita. Madaling sabihin, mahirap gawin. Lalo na kung pipilitin mong kalimutan yung taong hanggang ngayon ay mahal mo pa rin.”',
#   'orc_id': '0009-0008-6192-3817',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 23, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/421920839_3681651668783537_2266663650115388377_n.jpg'},
#  {'author_id': 162,
#   'journal_id': None,
#   'first_name': 'Kimberly',
#   'last_name': 'Pangilinan',
#   'middle_name': 'Buccat',
#   'public_name': None,
#   'email': 'kimberly.pangilinan022@gmail.com',
#   'email_verified': 'kimberly.pangilinan022@gmail.com',
#   'password': '5e946f70f7febdf7a9297b3434e2b54df9b776095128f67a095a3479e768ee7b',
#   'gender': 'Female',
#   'birth_date': datetime.date(2001, 10, 9),
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Web development, Software Engineering',
#   'bio': 'A passionate BS in Information Technology (QCU) student who loves learning, developing programs, and reading documentations',
#   'orc_id': '0009-0004-5992-7668',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 23, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '-',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/IMG_20240225_165349.jpg'},
#  {'author_id': 163,
#   'journal_id': None,
#   'first_name': 'Masterson Kurt',
#   'last_name': 'Malazarte',
#   'middle_name': 'Temporoza',
#   'public_name': None,
#   'email': 'mastersonkurt.malazarte17@gmail.com',
#   'email_verified': 'mastersonkurt.malazarte17@gmail.com',
#   'password': '6cb0aed9b9ce4c120638ba429290bfbbc8e47a2e3c8df0ff88f3f34b1b76e861',
#   'gender': 'Male',
#   'birth_date': datetime.date(2001, 11, 1),
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'sdfsdf',
#   'bio': '...',
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 23, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 164,
#   'journal_id': None,
#   'first_name': 'Fatima',
#   'last_name': 'Jacinto',
#   'middle_name': 'Caliboso',
#   'public_name': None,
#   'email': 'jacintofatimamae@gmail.com',
#   'email_verified': 'jacintofatimamae@gmail.com',
#   'password': '76b87dd7eeba8bb39864056fdd1ed5566f89e5de79ee84409e3e06756b7a280a',
#   'gender': 'Female',
#   'birth_date': datetime.date(2002, 7, 23),
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'Web Development, IT',
#   'bio': 'BSIT ',
#   'orc_id': '0009-0008-6192-3002',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 2, 23, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'Student',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/images (33).jpeg'},
#  {'author_id': 166,
#   'journal_id': None,
#   'first_name': 'Arnel',
#   'last_name': 'Mosenabre',
#   'middle_name': '',
#   'public_name': None,
#   'email': 'arnel.mosenabre05@gmail.com',
#   'email_verified': 'arnel.mosenabre05@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': 'Male',
#   'birth_date': datetime.date(2024, 2, 23),
#   'phone_number': '09745834774',
#   'afiliations': 'Student',
#   'position': 'STUDENT',
#   'country': 'United States',
#   'school_name': 'QCU',
#   'field_of_expertise': 'IT DEV',
#   'bio': 'I am me',
#   'orc_id': '0009-0002-3848-7283',
#   'url_orc_id': 'facebook,.com',
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Admin',
#   'marital_status': '',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': ' ',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 167,
#   'journal_id': None,
#   'first_name': 'Raven',
#   'last_name': 'Cuagon',
#   'middle_name': 'Gabatbat',
#   'public_name': None,
#   'email': 'revean.gabatbat.cuagon@gmail.com',
#   'email_verified': 'revean.gabatbat.cuagon@gmail.com',
#   'password': '21d776e96e55557619b3d6f6a91526566e1220d71dbeb128ff3c8e7fc601644f',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': 'N/A',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': 'Maginoo pero medyo bastos',
#   'orc_id': '0009-0001-1243-1014',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 168,
#   'journal_id': None,
#   'first_name': 'Richmonde',
#   'last_name': 'Ayag',
#   'middle_name': 'Magyaya',
#   'public_name': None,
#   'email': 'richmonde.ayag002@gmail.com',
#   'email_verified': 'richmonde.ayag002@gmail.com',
#   'password': '36a857358b65748c6d0102d54e33c9aad7d71820fd03512541f9d25fc2ff5c4e',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': '',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 169,
#   'journal_id': None,
#   'first_name': 'Johncel',
#   'last_name': 'Lamberte',
#   'middle_name': 'Casipong',
#   'public_name': None,
#   'email': 'johncel.lamberte14@gmail.com',
#   'email_verified': 'johncel.lamberte14@gmail.com',
#   'password': '163d35c26f0e52d59a9500e25213b2b9f3c7a01a48d2c4920184dc34a95a8a1f',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': '',
#   'position': 'STUDENT',
#   'country': 'Cyprus',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '0009-0001-4915-2115',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Admin',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 170,
#   'journal_id': None,
#   'first_name': 'Neil Justin',
#   'last_name': 'Nalam',
#   'middle_name': 'Pahunang',
#   'public_name': None,
#   'email': 'justinpahunang@gmail.com',
#   'email_verified': 'justinpahunang@gmail.com',
#   'password': '715f1fde9659150caa50894ef5a9ecdf09ae7391a06287bb8129e2e065d17d8a',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': '',
#   'position': 'STUDENT',
#   'country': 'Cyprus',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 173,
#   'journal_id': None,
#   'first_name': 'Quenie Elaiza',
#   'last_name': 'Narisma',
#   'middle_name': 'Paylangco',
#   'public_name': None,
#   'email': 'quenieelaiza.narisma08@gmail.com',
#   'email_verified': 'quenieelaiza.narisma08@gmail.com',
#   'password': 'd7e0410a561dd187d4fb4a52ef05beba8c36216d08614420050db84b1fe35022',
#   'gender': 'Female',
#   'birth_date': datetime.date(2002, 2, 8),
#   'phone_number': '',
#   'afiliations': 'Kkk',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': '',
#   'bio': 'Student ',
#   'orc_id': '0009-0000-8302-1517',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 174,
#   'journal_id': None,
#   'first_name': 'Claire',
#   'last_name': 'Jacob',
#   'middle_name': 'Samson',
#   'public_name': None,
#   'email': 'clairekaye.jacob18@gmail.com',
#   'email_verified': 'clairekaye.jacob18@gmail.com',
#   'password': '7b1c3024f98bff03edb36591f7f70ed3dae852ac8826b8ffbe9b54b006175210',
#   'gender': 'Female',
#   'birth_date': datetime.date(2001, 11, 18),
#   'phone_number': '',
#   'afiliations': 'COLLEGE OF COMPUTER STUDIES',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Student, IT Student',
#   'bio': '4th year IT Student at Quezon City University',
#   'orc_id': '0009-0007-0892-2033',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 175,
#   'journal_id': None,
#   'first_name': 'Raven',
#   'last_name': 'Cuagon',
#   'middle_name': 'Gabatbat',
#   'public_name': None,
#   'email': 'Arbeh420@gmail.com',
#   'email_verified': 'Arbeh420@gmail.com',
#   'password': '21d776e96e55557619b3d6f6a91526566e1220d71dbeb128ff3c8e7fc601644f',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': 'STUDENT',
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 176,
#   'journal_id': None,
#   'first_name': 'Maricar',
#   'last_name': 'Noel',
#   'middle_name': 'David',
#   'public_name': None,
#   'email': 'maricarnoel04@gmail.com',
#   'email_verified': 'maricarnoel04@gmail.com',
#   'password': 'ca4c77e84e046d363fa9fc125be39cd89936b46c340ba1daad7acf07d2f7df43',
#   'gender': 'Female',
#   'birth_date': datetime.date(2003, 10, 4),
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Canada',
#   'school_name': None,
#   'field_of_expertise': 'computer hardware',
#   'bio': '',
#   'orc_id': '0009-0003-1952-7208',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Married',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': 0,
#   'profile_pic': None},
#  {'author_id': 177,
#   'journal_id': None,
#   'first_name': 'Daphine',
#   'last_name': 'Agustin',
#   'middle_name': 'Arisgado',
#   'public_name': None,
#   'email': 'agustindaph@gmail.com',
#   'email_verified': 'agustindaph@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': 'Female',
#   'birth_date': datetime.date(1995, 11, 25),
#   'phone_number': '',
#   'afiliations': 'Student',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'Computer Hardware',
#   'bio': '',
#   'orc_id': '0009-0001-8557-8746',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': ' ',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 178,
#   'journal_id': None,
#   'first_name': 'Masterson Kurt',
#   'last_name': 'Malazarte',
#   'middle_name': 'Temporoza',
#   'public_name': None,
#   'email': 'masterson.kurt.malazarte@gmail.com',
#   'email_verified': None,
#   'password': '691554ac5f0c52332c4d5cc8f0477607782fe8fb3a4bd48066f391c3d5024da8',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 179,
#   'journal_id': None,
#   'first_name': 'Eric Johnes ',
#   'last_name': 'Delos Reyes',
#   'middle_name': 'Alavado ',
#   'public_name': None,
#   'email': 'ericjohnesdelosreyes@gmail.com',
#   'email_verified': 'ericjohnesdelosreyes@gmail.com',
#   'password': '79c00c6d17f2c76e4a755a19a7bc20b830e77fbb528fb12b7bf15b76a9443b5b',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': '',
#   'position': '',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': '',
#   'bio': '',
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 180,
#   'journal_id': None,
#   'first_name': 'Dylan',
#   'last_name': 'Gutierrez',
#   'middle_name': 'Deleon ',
#   'public_name': None,
#   'email': 'dylan.deleon.gutierrez@gmail.com',
#   'email_verified': 'dylan.deleon.gutierrez@gmail.com',
#   'password': 'f7616347f49b8be52ff2e926d5ff4990895c662211d64095e44b8573b5f8d1ba',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': '',
#   'position': '',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '0009-0001-1955-4877',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 181,
#   'journal_id': None,
#   'first_name': 'Ean',
#   'last_name': 'Pingol',
#   'middle_name': 'Velasco',
#   'public_name': None,
#   'email': 'ean.pingol09@gmail.com',
#   'email_verified': 'ean.pingol09@gmail.com',
#   'password': '7be41972eb33b31c2858f630aafe2c360dc9267744058e40b22a26629edfcef6',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': 'Jajaxxd',
#   'position': 'STUDENT',
#   'country': 'Cyprus',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': 'Hajafdd',
#   'orc_id': 'Fdcfdf',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'Hajaj',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 186,
#   'journal_id': None,
#   'first_name': 'Neil Justin',
#   'last_name': 'Nalam',
#   'middle_name': 'Pahunang',
#   'public_name': None,
#   'email': 'neiljustin.nalam05@gmail.com',
#   'email_verified': 'neiljustin.nalam05@gmail.com',
#   'password': '84d955ce81a2b24f2153ea7cef8c949dbfbee6c3352a30b8c4532bbdf9e99990',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '0009-0009-6125-4251',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 188,
#   'journal_id': None,
#   'first_name': 'Neil Justin',
#   'last_name': 'Nalam',
#   'middle_name': 'Pahunang',
#   'public_name': None,
#   'email': 'neiljustinnalam4@gmail.com',
#   'email_verified': 'neiljustinnalam4@gmail.com',
#   'password': 'ccddfe1abe2c090d190fd4e325891e906a627040874cd47af545e39d54cb8d2d',
#   'gender': 'Male',
#   'birth_date': datetime.date(2002, 9, 5),
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': 'Researcher/ Document',
#   'orc_id': '0009-0009-6125-4251',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 190,
#   'journal_id': None,
#   'first_name': 'Stephen',
#   'last_name': 'Heraldo',
#   'middle_name': 'Suyko',
#   'public_name': None,
#   'email': 'stephenzionheraldo@gmail.com',
#   'email_verified': 'stephenzionheraldo@gmail.com',
#   'password': '2cc4913c4db0b25d78c164dfff232c84960fb532cdf12f871f347c12b4c8c4e2',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Math',
#   'bio': '',
#   'orc_id': '0009-0004-0647-5610',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': '../Files/uploaded-profile/remix-rumble-400x400.jpg'},
#  {'author_id': 215,
#   'journal_id': 1,
#   'first_name': 'Elyana',
#   'last_name': 'Española',
#   'middle_name': 'Depamallo',
#   'public_name': None,
#   'email': 'elyana.espanola01@gmail.com',
#   'email_verified': 'elyana.espanola01@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': 'Female',
#   'birth_date': datetime.date(2002, 1, 1),
#   'phone_number': '09690971146',
#   'afiliations': 'QCU',
#   'position': 'STUDENT',
#   'country': 'Jersey',
#   'school_name': 'Quezon city University',
#   'field_of_expertise': 'Web Developer, UI Designer, IT, Computer',
#   'bio': 'HAHAAHAHHAAHHA',
#   'orc_id': '0009-0007-0600-209X',
#   'url_orc_id': 'https://orcid.org/0009-0007-0600-209X',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 216,
#   'journal_id': None,
#   'first_name': 'Dharren Paul',
#   'last_name': 'Sanchez',
#   'middle_name': '',
#   'public_name': None,
#   'email': 'dharren.sanchez023@gmail.com',
#   'email_verified': 'dharren.sanchez023@gmail.com',
#   'password': 'b548573902e2536732a5dcabde9a5745ed618dd5bd50f8e091e2ec6fd81ac0d6',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': 'QCU',
#   'position': 'STUDENT',
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': 'Developer HAAAAAAAAAAAAAAAAAAAAAAAAAAA',
#   'bio': '',
#   'orc_id': '0009-0003-1767-5960',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': '../Files/uploaded-profile/sanchez.png'},
#  {'author_id': 219,
#   'journal_id': None,
#   'first_name': 'Ayag',
#   'last_name': 'Ayag',
#   'middle_name': 'Magyaya',
#   'public_name': None,
#   'email': 'hiromiikun40@gmail.com',
#   'email_verified': 'hiromiikun40@gmail.com',
#   'password': '1c6c5efd48c36d921f8be4279266778038c03bf33202fc54d9c5fa97a6528f3b',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0009-0001-5449-5251',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 220,
#   'journal_id': None,
#   'first_name': 'Dylan',
#   'last_name': 'gutierrez',
#   'middle_name': 'deleon ',
#   'public_name': None,
#   'email': 'dylangutz2000@gmail.com',
#   'email_verified': 'dylangutz2000@gmail.com',
#   'password': '4f3d82c6231d74a8fef6627f2d2d83978a23a0544f08fda0cbcd62eec25e2056',
#   'gender': 'Male',
#   'birth_date': datetime.date(2000, 11, 16),
#   'phone_number': '',
#   'afiliations': 'student',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'it',
#   'bio': '',
#   'orc_id': '0009-0001-1955-4577',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 221,
#   'journal_id': None,
#   'first_name': 'Juan',
#   'last_name': 'Dela Cruz',
#   'middle_name': 'Tan',
#   'public_name': None,
#   'email': 'jhexphell@gmail.com',
#   'email_verified': 'jhexphell@gmail.com',
#   'password': 'd07e7c4cce2afb5fdab874b1f6c1f95a06564921bad3486805e5bd27fad62457',
#   'gender': 'Male',
#   'birth_date': datetime.date(2002, 4, 25),
#   'phone_number': '',
#   'afiliations': 'Music Lover',
#   'position': 'STUDENT',
#   'country': None,
#   'school_name': 'Quezon City University',
#   'field_of_expertise': 'Umasa',
#   'bio': '',
#   'orc_id': '0009-0008-6192-3822',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/417544853_746745870739003_243084953764655823_n.jpg'},
#  {'author_id': 284,
#   'journal_id': None,
#   'first_name': 'Kyle Angeline',
#   'last_name': 'David',
#   'middle_name': 'Ocbeña',
#   'public_name': None,
#   'email': 'kyleangelinedavid27@gmail.com',
#   'email_verified': 'kyleangelinedavid27@gmail.com',
#   'password': '1f55b04b4811898500cc3a1f46c8d35fd2e6c271f21ee6662bf247c31b0e5273',
#   'gender': 'Female',
#   'birth_date': datetime.date(2002, 7, 27),
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'IT, Computer, Research',
#   'bio': 'Hello World!',
#   'orc_id': '0009-0006-9470-9898',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 285,
#   'journal_id': None,
#   'first_name': 'JOHN',
#   'last_name': 'LAMBERTSS',
#   'middle_name': 'CASIPONG',
#   'public_name': None,
#   'email': 'lambertssjohn16@gmail.com',
#   'email_verified': 'lambertssjohn16@gmail.com',
#   'password': '85c98f43b0a6bef14e487bc77da1057b9777630164be065f79ca4cfdd28b8fd9',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Liberia',
#   'school_name': '',
#   'field_of_expertise': ', IT, COMPUTER',
#   'bio': 'HAHA',
#   'orc_id': '0009-0000-0976-8399',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 287,
#   'journal_id': None,
#   'first_name': 'Eloisa Marie',
#   'last_name': 'Baylon',
#   'middle_name': 'Maglana',
#   'public_name': None,
#   'email': 'eloisa012816@gmail.com',
#   'email_verified': 'eloisa012816@gmail.com',
#   'password': 'dc59ff69ba37853ebe3cd04c30db24dc6a55344fa1665317c4413587248222b1',
#   'gender': 'Female',
#   'birth_date': datetime.date(1998, 1, 10),
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Information Technology',
#   'bio': '',
#   'orc_id': '0009-0004-0778-2671',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 288,
#   'journal_id': None,
#   'first_name': 'Raven',
#   'last_name': 'Cuagon',
#   'middle_name': 'G.',
#   'public_name': None,
#   'email': 'arbeh3410@gmail.com',
#   'email_verified': None,
#   'password': '44a3d21b5c44503b9fc88ac83c08ccb7018f31bb046e7b225e150a483a520a0e',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0009-0007-8222-8146',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 290,
#   'journal_id': None,
#   'first_name': 'Allen Jo',
#   'last_name': 'Pascua',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'allenjopascua09@gmail.com',
#   'email_verified': 'allenjopascua09@gmail.com',
#   'password': '182c20340281cff3e42f1e037735dbe9e6228ade413054437dcb4369ab5251a3',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0009-0003-6272-3319',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 291,
#   'journal_id': None,
#   'first_name': 'Fatima ',
#   'last_name': 'Jacinto',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'fatimamaejacinto30@gmail.com',
#   'email_verified': None,
#   'password': '76b87dd7eeba8bb39864056fdd1ed5566f89e5de79ee84409e3e06756b7a280a',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': 'STUDENT',
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0009-0004-6357-2572',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None},
#  {'author_id': 293,
#   'journal_id': None,
#   'first_name': 'Kimberly',
#   'last_name': 'Pangilinan',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'kimberly.b.pangilinan@gmail.com',
#   'email_verified': 'kimberly.b.pangilinan@gmail.com',
#   'password': 'b44bfd704c6bfe6a5f122b171b03a8d8d02dd8a8eddff702d3c006ddea986bf2',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0000-0003-2824-785X',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None},
#  {'author_id': 294,
#   'journal_id': None,
#   'first_name': 'Angelito',
#   'last_name': 'Bautista Jr',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'angelito.bautista.jr@qcu.edu.ph',
#   'email_verified': 'angelito.bautista.jr@qcu.edu.ph',
#   'password': '5cde0ddf4a8677718dd87a06c511d91fbf8b35446914e3bcb22c738dc4a9528a',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0000-0001-6591-7280',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 10, 13, 37, 23),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None},
#  {'author_id': 295,
#   'journal_id': None,
#   'first_name': 'Juan',
#   'last_name': 'Dela Cruz',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'jhexphel00@gmail.com',
#   'email_verified': None,
#   'password': 'd07e7c4cce2afb5fdab874b1f6c1f95a06564921bad3486805e5bd27fad62457',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0000-0002-1825-0097',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 11, 2, 30, 14),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None},
#  {'author_id': 296,
#   'journal_id': None,
#   'first_name': 'Ben',
#   'last_name': 'Tenison',
#   'middle_name': 'Odon',
#   'public_name': None,
#   'email': 'marvin.gozo23@gmail.com',
#   'email_verified': 'marvin.gozo23@gmail.com',
#   'password': 'f8d6fbb6b4e0c42a0cfa76fb9978f1e9d326ba3de720c19a2f55f973a6cde889',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Math',
#   'bio': '',
#   'orc_id': '0009-0008-9311-7385',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 15, 11, 23, 29),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': 0,
#   'profile_pic': None},
#  {'author_id': 297,
#   'journal_id': None,
#   'first_name': 'Gabrielle Louise',
#   'last_name': 'David',
#   'middle_name': 'Ocbena',
#   'public_name': None,
#   'email': 'godavid1@up.edu.ph',
#   'email_verified': 'godavid1@up.edu.ph',
#   'password': 'd859132a547fac714c9c26e72b9da2acee942683818c61befc6eeb6beffc6875',
#   'gender': 'Male',
#   'birth_date': datetime.date(2000, 11, 1),
#   'phone_number': '',
#   'afiliations': 'University of the Philippines',
#   'position': 'Student',
#   'country': 'Qatar',
#   'school_name': None,
#   'field_of_expertise': 'Human Settlement, Ecology, Transportation',
#   'bio': 'Researcher',
#   'orc_id': '0009-0008-0271-517X',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 16, 8, 35, 9),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/picture.jpg'},
#  {'author_id': 299,
#   'journal_id': None,
#   'first_name': 'asda',
#   'last_name': 'asd',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'example@gmail.com',
#   'email_verified': None,
#   'password': 'f8d6fbb6b4e0c42a0cfa76fb9978f1e9d326ba3de720c19a2f55f973a6cde889',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 16, 12, 55, 37),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None}]

# %%
ids = [row['author_id'] for row in data]
field_of_expertises = [row['field_of_expertise'] for row in data]
bios = [row['bio'] for row in data]

# %%
field_of_expertises
# Out:
# ['',
#  'Web Development',
#  'Web Development',
#  'Web Development',
#  'Web development, Software Engineering',
#  'sdfsdf',
#  'Web Development, IT',
#  'IT DEV',
#  None,
#  None,
#  None,
#  None,
#  '',
#  'Student, IT Student',
#  None,
#  'computer hardware',
#  'Computer Hardware',
#  None,
#  '',
#  None,
#  None,
#  None,
#  None,
#  'Math',
#  'Web Developer, UI Designer, IT, Computer',
#  'Developer HAAAAAAAAAAAAAAAAAAAAAAAAAAA',
#  None,
#  'it',
#  'Umasa',
#  'IT, Computer, Research',
#  ', IT, COMPUTER',
#  'Information Technology',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Math',
#  'Human Settlement, Ecology, Transportation',
#  None]

# %%
# Preprocessing
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

modified_bios = []

for n, bio in enumerate(bios):
    if bio is None:
        modified_bios.append("")
        continue
    temp = bio.lower().split(" ")
    temp = [''.join([letter for letter in word if letter.isalnum()]) for word in temp]
    temp = [word for word in temp if word not in stop_words]
    temp = ' '.join(temp)
    modified_bios.append(temp)
    
# for n, field_of_expertise in enumerate(field_of_expertises):
#     temp = field_of_expertise.lower().split(" ")
#     temp = [''.join([letter for letter in word if letter.isalnum()]) for word in temp]
#     temp = [word for word in temp if word not in stop_words]
#     temp = ' '.join(temp)
#     field_of_expertise[n] = temp
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kimbe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
modified_bios
# Out:
# ['',
#  '',
#  '',
#  'move anim na letrang salita madaling sabihin mahirap gawin lalo na kung pipilitin mong kalimutan yung taong hanggang ngayon ay mahal mo pa rin',
#  'passionate bs information technology qcu student loves learning developing programs reading documentations',
#  '',
#  'bsit ',
#  '',
#  'maginoo pero medyo bastos',
#  '',
#  '',
#  '',
#  'student ',
#  '4th year student quezon city university',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'hajafdd',
#  '',
#  'researcher document',
#  '',
#  'hahaahahhaahha',
#  '',
#  '',
#  '',
#  '',
#  'hello world',
#  'haha',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'researcher',
#  '']

# %%
modified_field_of_expertises = []

for n, field_of_expertise in enumerate(field_of_expertises):
    if field_of_expertise is None:
        modified_field_of_expertises.append("")
        continue
    temp = field_of_expertise.lower().split(" ")
    temp = [''.join([letter for letter in word if letter.isalnum()]) for word in temp]
    temp = [word for word in temp if word not in stop_words]
    temp = ' '.join(temp)
    modified_field_of_expertises.append(temp)

# %%
modified_field_of_expertises
# Out:
# ['',
#  'web development',
#  'web development',
#  'web development',
#  'web development software engineering',
#  'sdfsdf',
#  'web development',
#  'dev',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'student student',
#  '',
#  'computer hardware',
#  'computer hardware',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'math',
#  'web developer ui designer computer',
#  'developer haaaaaaaaaaaaaaaaaaaaaaaaaaa',
#  '',
#  '',
#  'umasa',
#  'computer research',
#  ' computer',
#  'information technology',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'math',
#  'human settlement ecology transportation',
#  '']

# %%
joined_data = [field_of_expertise.replace(" ", "") + " " + bio if bio is not None else None for field_of_expertise, bio in zip(modified_field_of_expertises, modified_bios)]

print(joined_data)
# Out:
# [' ', 'webdevelopment ', 'webdevelopment ', 'webdevelopment move anim na letrang salita madaling sabihin mahirap gawin lalo na kung pipilitin mong kalimutan yung taong hanggang ngayon ay mahal mo pa rin', 'webdevelopmentsoftwareengineering passionate bs information technology qcu student loves learning developing programs reading documentations', 'sdfsdf ', 'webdevelopment bsit ', 'dev ', ' maginoo pero medyo bastos', ' ', ' ', ' ', ' student ', 'studentstudent 4th year student quezon city university', ' ', 'computerhardware ', 'computerhardware ', ' ', ' ', ' ', ' hajafdd', ' ', ' researcher document', 'math ', 'webdeveloperuidesignercomputer hahaahahhaahha', 'developerhaaaaaaaaaaaaaaaaaaaaaaaaaaa ', ' ', ' ', 'umasa ', 'computerresearch hello world', 'computer haha', 'informationtechnology ', ' ', ' ', ' ', ' ', ' ', ' ', 'math ', 'humansettlementecologytransportation researcher', ' ']

# %% [markdown]
# ## Articles

# %%
sql_query= """
            SELECT * FROM article WHERE status = 1 
           """

# %%
db.ping(reconnect=True)
cursor = db.cursor()
cursor.execute(sql_query)
data = cursor.fetchall()

# %%
data
# Out:
# [{'article_id': 3,
#   'author_id': 1,
#   'journal_id': 1,
#   'issues_id': 1,
#   'title': 'Addressing The Trade Offs Between Labor Productivity And Employment Among Call Center Agents In Metro Manila',
#   'author': 'Caroline Romero, Luz Banes, Faustino Tolentino, Gertrudes Ochoa',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "Call center agents work in a telephone call center where they receive calls from customers inquiring about a product or service and make outgoing calls to current and potential customers. They must assist customers in a variety of areas, including billing, service issues, and orders, log calls made or received, and enter customer data into a specialized database. Additional responsibilities, such as sales and customer retention, are performed on a computer at a workstation or cubicle by agents in a call center. The majority of the work utilizes computers, software applications, and the internet. They are essential to the existence of all of these call centers. The issue at hand is whether there are labor productivity trade-offs and whether human labor has been replaced by technology. In light of this, this paper will discuss the factors that contribute to the labor productivity of call center agents in Metro Manila, resulting in an increase in employment despite the reliance on technology. Others believed that technological progress paved the way for the replacement of human labor, thereby decreasing the number of employed people or increasing unemployment. Unobserved in the paper's findings was a direct relationship between an increase in labor productivity and a rise in unemployment. In this study, the authors employed qualitative research characteristics, such as the relationship between researcher and participant. Qualitative research always gathers verbal and open-ended information. Former students of UDM's Marketing course, the participants are currently employed in Metro Manila as marketers. In this paper, agents from a call center demonstrated that human labor is still the master of technology and that their efforts are required to produce more output and services. Labor productivity equals the sum of human labor or labor resources, technological innovation, and capital expenditures.",
#   'keyword': 'call center representatives, labor productivity, and employment',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 7, 26, 22),
#   'publication_date': datetime.datetime(2023, 12, 12, 22, 33, 14),
#   'archive_date': None},
#  {'article_id': 4,
#   'author_id': 1,
#   'journal_id': 1,
#   'issues_id': 1,
#   'title': 'The Effects of Social Isolation, Remote Work Satisfaction, and Stress on Perceived Remote Work Productivity of Business Process Outsourcing Employees in National Capital Region: A Gender Difference Approach',
#   'author': 'Renielle S. Rogel',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "his paper assessed the effects of social isolation, remote work satisfaction and stress on the perceived remote work productivity between male and female business process out- sourcing employees in national capital region. Specifically, it attempted to respond to the fol- lowing inquiries on (1) the effect of social isolation on perceived remote work productivity, re- mote work satisfaction, and stress; (2) the effect of stress on remote work satisfaction and perceived remote work productivity; (3) the effect of remote work satisfaction on perceived remote work productivity; (4) the mediating effect of remote work satisfaction on the relation- ship between social isolation and perceived remote work productivity: (5) the mediating effect of stress on the relationship between social isolation and perceived remote work productivity; and (6) the moderating effect of respondents' sex on the relationship between stress and per- ceived remote work productivity and remote work satisfaction and perceived remote work productivity. In this current scenario, when remote working is still a debating point, this study further provided necessary information and support to the government's September 2022 di- rective to allow information technology and business processing management or business processing outsourcing (IT-BPM/BPO) companies in economic zones to adopt up to 100% work-from-home (WFH) arrangement without losing tax perks (DTI, 2022).",
#   'keyword': 'social isolation, work satisfaction, stress, work productivity',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 7, 30, 47),
#   'publication_date': datetime.datetime(2023, 12, 12, 22, 33, 18),
#   'archive_date': None},
#  {'article_id': 5,
#   'author_id': 1,
#   'journal_id': 1,
#   'issues_id': 1,
#   'title': 'The Effectiveness of Electronic Wallet as alternative for cash transaction for Quezon City Entrepreneurship Students',
#   'author': 'Dr. Melissa Y. Caballes, Dr. Ronilo B. Ramilo, Prof. Lorna Suyat, Prof. Marjorie Daganas',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "The study sought to assess the effectiveness of electronic wallets as an alternative cash transaction for Quezon city university entrepreneurship students in the new normal. The following hypothesis shall be tested at 0.05 margin of error. There is no significant difference in the respondents' assessment of the effectiveness of electronic wallets as an alternative cash transaction of Quezon city university entrepreneurship students in the new normal when they are grouped according to the profile of the respondents. The researcher used a descriptive method for the research, to gather information about the present existing condition. The researcher decided to use the sampling technique by selecting at least 250 students as respondents. The respondents' demographic profile comprises the following: age, gender and college year level. The sampling techniques are non-probability sampling techniques used when respondents are chosen because of their appropriateness in the conduct of a study. This is designed to have general description of the effectiveness of electronic wallets as an alternative cash transaction for Quezon city university entrepreneurship students. The researcher used systematic random sampling for Quezon city university entrepreneurship students who have been into online classes. The gathered data from respondents were tabulated and interpreted. The main instrument used in the collection of data was a structured google form survey questionnaire. The questionnaire was a pattern up to the questions used in a relevant study. The questionnaire was formulated based on the related literature gathered. The instrument was divided into three (3) parts. The first part depicts the demographic profile of the respondents which includes their age, sex and year level. The second part of the questionnaire is about the respondent's assessment of the effectiveness of electronic wallets as an alternative cash transaction for Quezon city university entrepreneurship students in the new normal. The third part delves into the significant differences between the respondents. The gathered data from respondents were tabulated and interpreted.",
#   'keyword': 'electronic wallet, accuracy of payment, on-time delivery, accessibility and efficiency, security and reliability',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 12, 12, 22, 33, 22),
#   'archive_date': None},
#  {'article_id': 6,
#   'author_id': 1,
#   'journal_id': 1,
#   'issues_id': 1,
#   'title': "Seafarers' Safety of Life at Sea (SOLAS) and Skills Performance A Basis for Risk Reduction Management Model",
#   'author': 'Luz P. Banes, Elena R. Cernias, Mary Grace Daguiso',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "In the Seafarer's Safety of Life at Sea (SOLAS 74) program, there is no mention of how seafarers will be protected from dangerous diseases, including the COVID 19 virus. The Philippines, according to The World Bank's 2014 report for the East Asia Region, has the highest absolute rate of maritime casualties, which is 40 % higher than Indonesia, which ranks second. According to World Bank data, 228 ships are involved in accidents and 303 people are killed annually in the Philippines. Maritime Industry Authority (MARINA) reported in 2019 that the number of maritime accidents investigated increased from 2016 to 2019: 2016 43 cases, 2017 - 48 cases, 2018 -152 cases, and 2019-148 cases, for a total of 391. 273 of these incidents are classified as serious accidents. In order to promote safety aware- ness, the International Maritime Organization (IMO) mandated that all ship owners require all seafarers to complete the SOLAS program before joining the vessel. To evaluate the program, the CIPP model will be applied while surveying and collecting data from the three types of respondents: one administrative member of the Maritime Institute, two retired seafarers, and six active seafarers. Therefore, the purpose of this study is to evaluate the SOLAS74 program's impact on the careers of seafarers and to propose a risk reduction management model to enhance the SOLAS program, which will ensure the protection of seafarers during pandemics at sea.",
#   'keyword': 'Safety of life at sea program (SOLAS), seafarers, MARITIME accidents, risk reduction management program',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 15, 7, 33, 55),
#   'archive_date': None},
#  {'article_id': 7,
#   'author_id': 1,
#   'journal_id': 1,
#   'issues_id': 1,
#   'title': "Online Shopping Experience of UDM Faculty Members in Manila's Market Place",
#   'author': 'Elena R. Cerenias, Luz Banes, Rolando Maso, Reggie Bautista',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "The Universidad de Manila (UDM), formerly known as City College of Manila, was established in 1995 by the City Council of Manila's Ordinance No. 7885. On its 25th Founding Anniversary in April 2020, UDM, implemented a repositioning strategy to adhere to its original mission as the preeminent science and technology higher education institution in Manila, with Education 4.0 as the focal point of its core course offerings. The Universidad de Manila Portal was designed for current and prospective students and faculty. The Universidad de Manila Portal ena- bled faculty members to perform a variety of academic-related tasks, including viewing course ad- mission lists/status, the academic calendar, lectures, and grades/performance. Beyond class hours, the portal facilitates communication between professors and students. This study is an initi- ative usability analysis to determine the needs of the UDM community and expand the University Information and Communications Technology Office's service offerings (ICTO). The study deter- mined the Faculty Portal's usability in terms of its features and frequency of use. This serves as the foundation for enhancing the university-wide Faculty Portal usage policy.",
#   'keyword': 'access, faculty portal, features, usability, Universidad de manila',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 15, 7, 33, 55),
#   'archive_date': None},
#  {'article_id': 8,
#   'author_id': 1,
#   'journal_id': 1,
#   'issues_id': 1,
#   'title': 'G Sa Ugbo: Food Safety and Sanitation Practices of Food Establishments in Tondo, Manila',
#   'author': 'John Christian Espinola, Ell Clifferson Gallardo, Joshua Gabriel P. Ureta, Princess Jazmine Silvestre, John Benedick D. Manalo, Alexandra Marie A. Nadong, Frances Kaira M. Fernandez, Ashley Jade J. Arango, Clyde Cabales, Carlos Joshua Catanes, Gian Gagari',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': 'Street food has paved its way as an important food category when it comes to Filipino food because it\'s reasonably priced, convenient, and a great way to give a hint to a country\'s culture (Tee, S., n.d.). Ugbo Street Food is one of the famous places in Tondo, Manila that offers numerous food stalls that serve inexpensive snacks and desserts until the late hours of the night. The goal of the study is to increase awareness towards health-related concerns associated with food safety and sanitation on eating street foods and to promote Ugbo Street food as one of the famous food destinations. 411 food aficionados completed a 39-likert type survey developed by the researchers. The instrument was validated by industry and food experts and has a Cronbach\'s Alpha of 0.966. The customers rated sanitation of service area and equipment, food handling and customer service, and pest and waste man- agement of the food establishments in Ugbo, Tondo Manila to be "very good", especially on food visibility and equipment. Items on food preparation such as exposure, cooking, and han- dlers\' sanitation practices ranked lowest. Significant differences (p<.05) were found in the as- sessment based on the respondents\' frequency of visit, companions, amount spent, and edu- cational attainment. This shows that food safety and sanitation were not consistently prac- ticed. The researchers suggest that owners and food handlers be given formal trainings and certification, and that barangay health authorities to regularly monitor compliance to ensure consumers\' safety and sustainability of micro-businesses.',
#   'keyword': 'food safety, sanitation, street food, food handling, consumer',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 15, 7, 33, 55),
#   'archive_date': None},
#  {'article_id': 9,
#   'author_id': 1,
#   'journal_id': 1,
#   'issues_id': 1,
#   'title': 'Responsiveness of Financial Institutions to Tourism-Related Business in Puerto Princesa City',
#   'author': 'Mary Grace A. Masdo',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "Puerto Princesa City, Palawan is known for its tourism attractions from the time the Under- ground River was included in the seven wonders of nature around the world. The enormous in- crease of tourist visitors resulted in increa tourism-related businesses. Financial institutions start- ed to proliferate as well and it plays a very significant role in the tourism industry by providing fi- nancial services to tourism-related businesses. The study gathered data on the profile of tourism-related business in terms of its capital structure, management and employment. Likewise, data was also gathered to describe the profile of financial institutions in terms of classifications and products and services offered. The study was conducted to determine the economic link between tourism related businesses and financial institutions. It aimed to determine the opportunities and problems affecting the growth of the tourism related businesses and financial institutions. Moreover, it was conducted to determine how the products and services of the financial institutions help in the growth and development of tourism-related businesses. The study used purposive sampling with forty (40) respondents from tourism-related busi- nesses and fifteen (15) respondents from financial institutions. Survey questionnaire was used. The findings revealed that the increase of tourism-related businesses contribute to the development of the city in terms of employment. Moreover, it brought opportunities to financial institutions. Tourism-related businesses obtained its borrowings for its short term and long-term financing needs from banks and microfinance institutions. Banking institutions catered financial services to those who passed their standards while microfinance institutions catered to those who cannot pass the stringent qualifications of the bank. The existence of commercial banks was not really relevant to the development of eco-tourism business in the city as it is composed mostly of the micro and small businesses. Only one bank has offered a financial product designed to fit the current needs of the city for the recovery and development of its tourism sector. To be responsive to the needs of the city's eco-tourism industry, specifically tourism-related businesses in particular, a consultative process among various stakeholders composed of financial service providers, clients/users of financial services such as the tourism industry. government institutions, development partners and international organizations is needed to provide inputs and feedback, share knowledge, and come up with supports and initiatives such as helping the recovery and development of the city tourism through providing constant government intervention and financial service that is tailored fit to the needs of the tourism-related businesses.",
#   'keyword': '',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 15, 7, 33, 55),
#   'archive_date': None},
#  {'article_id': 10,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'A Classroom-based Action Research on Selected First Year Infor- mation Technology Students of Quezon City University for the Sec- ond Semester of Academic Year 2021-2022',
#   'author': 'Donalyn Dizon, Rafael Tabunda, Josephine Uy',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "This action research reports the results of a classroom-based study conducted in general education courses to examine whether the integration of video recordings would contribute to the improvement of the oral communication skills of students. It also aims to find out what are the perceptions of students using video recording their online learning. twenty students enrolled in general courses participated in this study. To determine the effectiveness of video recording on the students' oral communication skills, the speaking test of IELTS was modified as pre- and post-test. In addition to the analysis of the scores assigned to the students by two raters using Cohen's kappa, an analysis of students' speaking in pre- and post-test was undertaken to determine whether measures of students' oral communication output differ as a result of the video recording. The results suggest that the incorporation of video recordings into the speaking activities did not have significant improvement in their oral communication skills. However, the analysis of the qualitative data showed that the students were able to apply those communication skills in speaking, and they have gained confidence and insights on how to improve their skills through the comments given by the researchers.",
#   'keyword': 'speaking, video recording, oral communication, integration, online learning',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 3, 23, 46),
#   'archive_date': None},
#  {'article_id': 11,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Online Learning Implementation Challenges of Laboratory Teachers during Covid-19 Pandemic',
#   'author': 'Dolores O. San Juan, Jocelyn P. Remoto',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "In March 2020, the Commission on Higher Education (CHED) advised higher education institutions (HEIS) to respond to the Covid-19 upsurge (De Vera III, 2020). For many of the teachers converting face-to-face classes to an online format is a serious difficulty, especially to teachers teaching laboratory subjects and other hands-on subjects. This study investigates higher education institutions (HEI) laboratory teachers' perspectives on teacher, school, curricular, and student impediments to e-learning deployment during the Covid-19 epidemic. The results of this study provide important recommendations for policy-makers, designers, developers, and researchers, enabling them to become more familiar with the essential elements of the successful implementation of e-learning systems during the Covid-19 pandemic.",
#   'keyword': 'challenges, online learning, Covid-19 pandemic, laboratory teachers, implementation.',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 9, 3),
#   'archive_date': None},
#  {'article_id': 12,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Leadership Style and Institutional Sustainability Assessment of Local Universities and Colleges in NCR, Philippines: Towards Institutional Development',
#   'author': 'Glenda A. Rebucas, DBA, LPT',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': 'The Local Universities and Colleges (LUCs), being dynamic organizations, need educational leaders who can effectively implement necessary changes for institutional development. Due to demands for reform and accountability, LUCs must meet strict educa- tional standards or face serious consequences. Schools must find leaders that are not just willing, but able to face these challenges by successfully initiating change both for the im- provement of the system as well as its ultimate reform. The Commission on Higher Education (CHED) promotes Institutional Sustainability Assessment (ISA) because it can serve as a learning process for the HEIs and contribute to its continuing quality cycle for its institutional development. In response to the lack of informed research concerning educational leadership styles correlating to institutional sustainability assessment and outcomes in LUCs, the researcher is motivated to pursue this study and aims to contribute to this pressing issue of LUCS for quality mechanisms, despite of its high political influences and bureaucratic system that affect or hinder the LUCs development. Hence, the purpose of the study is to determine the situational leadership style of the individuals most responsible for changing or maintaining a system and what factors might affect the ability of a person to make meaningful changes in a school setting and the relationship of these leadership styles to ISA Key Results Areas. Descriptive method was used in the study using the Leadership Style Instrument adopt- ed from Hershey and Blanchard and the Self-Evaluation Document of the CHED ISA adminis- tered to the LUCs Administrative and Academic Heads, using random sampling technique. The study revealed that coaching, delegating, and directing are the leadership styles exhibited by the school administrators to a moderate extent in a situation. This implies that development level of the subordinates is still in low level. The sampled LUCS \'very often practiced" the institutional sustainability indicators, as a whole. And, it is only the directing leadership style that has a significant positive relationship with governance (r=.224, >:.05); quality of teaching and learning (r=.255, >;.05); and exposure, research and creative work (240, .05). This implies that the increase in the use of directing leadership style will also increase the practice of institutional sustainability such as governance; quality of teaching and learning; and exposure, research and creative work.',
#   'keyword': 'challenges, online learning, Covid-19 pandemic, laboratory',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 9, 22),
#   'archive_date': None},
#  {'article_id': 13,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Physical Plant and Instructional Support Facilities of Diocese of Imus Catholic Educational System (DICES), Inc. Schools',
#   'author': 'Romar B. Reyes',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "The purpose of the study is to evaluate the physical plant and instructional support facilities of Diocese of Imus Catholic Educational System, Inc.. The study used descriptive research approach with the involvement of a total population of seven hundred ninety-three (793) Grade 10 learners, teachers, principals, and physical plant coordinators and were represented by two hundred sixty-two (262) randomly selected proportional respondents. The respondents provided commendable evaluation in varying degrees of their existing school building and facilities, space provisions, and safety, health, and well-being measures. There are, however, observed consistent lower acceptable ratings like the individual monitoring of cleanliness and sanitation of comfort rooms, ramps and lifts for physically impaired children, drainage and sewage system, properly labeled and barcoded equipment, well-planned entrance and exit points of the building and facilities, and space provisions for adequate clinic size. The respondents likewise provided varying assessment of within the acceptable limits for their schools' current instructional support facilities. Nonetheless, found with least ratings but still acceptable include emergency showers, functional exhaust fans, designation of qualified and well-trained laboratory aides, readily available first-aid supplies in chemistry laboratories, provision of updated computers with operation manual and software applications with license in computer laboratories; provision of separate rooms for boys and girls, adequate Personal Protective Equipment, and first-aid supplies for the TLE rooms. This is diverse appreciation of schools compliance to the prescribed standards for school buildings and facilities, space provisions and safety, health, and well-being. And except for schools' classrooms, appreciable differences in the evaluation of computer and science laboratories, TLE rooms, and libraries.",
#   'keyword': 'challenges, online learning, Covid-19 pandemic, laboratory teachers, implementation',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 9, 34),
#   'archive_date': None},
#  {'article_id': 14,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Evaluation of QCU Graduating Students: Basis for the Development and Enhancement of Entrepreneurship Curriculum Program',
#   'author': 'Prof Emmanuel S. Garcia Prof. Jo Ann General, Dr. Jona Marquez, Prof. Daryl Panganiban, Prof. Jessica Sintos- Pagulayan, Prof. Alice Morales, Prof. Vicky Sierra',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "Every institution in the higher learning education periodically reforms the curriculum offered to the students ensuring the level of consistency and quality across different types of education provisions and age group preparing them to thrive and shape the future for employment. This is to amplify the lack of student awareness of their position within the curriculum for the enhancement through the use of visibility of learning trajectories across the curriculum for the improvement through the use of mapping tool such as learning enhancement for teachers that reinforce and expand their knowledge of the major ideas and concepts in developing curriculum with familiarity with a range of instructional strategies, and the skills, to implement those strategies in the classroom for students leaming across their careers, from their initial training to continuing professional development. Providing learning opportunities that will require profound changes of teacher's capability to improve understanding which is heavily influenced towards the application of the enhanced curriculum for better employment. In line to this study, we used descriptive method through survey questionnaire with the following variables: subject understanding, personal qualities, skills, and employability using likert scale to determine the sufficiency, adaptability, correctness as part of research methodology with 307 graduating students for S.Y. 2022-2023",
#   'keyword': 'curriculum enhancement, subject understanding, personal qualities, skill, employability',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 9, 41),
#   'archive_date': None},
#  {'article_id': 15,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Dirty Dozen: Selected Human Factors as a Contributing component to the Academic Performance of 3rd Year BSAMT Students of A.Y. 2021-2022 of Philippine State College of Aeronautics in the New Normal Learning',
#   'author': 'John Patrick J. Diokno, Martin Andrew L. Apostol, Adrian Paul A. Haresco, Jadren Kyle C. Santiago, Jose Mari J. Ygbuhay, MEAM',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "According to Piscopo (2022), the dirty dozen is a concept of Gordon Dupont consisting of twelve human factors that affect one's performance, in the field of aviation, especially for aircraft mechanics, The dirty dozen are the factors that affect an individual and cause human errors. Several human factors contribute to the low academic performance of students in the Philippines who are currently studying in the new normal setup or online learning. According to Rotas & Cahapay (2020), one of the main challenges that students are currently facing in the online learning setup is the overloaded lesson activities. This particular difficulty of having to submit unjustified load activities from different subjects in just a week makes the students feel that the value of learning in the lesson is lost and they are just doing the activity for the sake of compliance. This is why this study aims to analyze how human factors contribute to the academic performance of the 3rd year BSAMT students of PhilSCA. The results of this study will be used to make the proposed recommendatory framework on how to mitigate the contributions of selected human factors to a student's academic performance.",
#   'keyword': 'academic performance, aviation, PhilSCA',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 9, 51),
#   'archive_date': None},
#  {'article_id': 16,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Course Preferences among Education Students',
#   'author': 'Dr. Jenelyn G. Sabellina, Marietes B. Zamora, Kimberly Paderanga, Maria Melina A. Rodriguez',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "Education is universally recognized as the answer to socio-economic problems of the world. Hence, course selection is one of many important choices that students will make in determining future plans. It becomes one of the biggest dilemma and challenge in any student's life. Hence, the study sought to investigate the course preference among students. The study used quantitative methods of data collection. The quantitative method was done through a survey questionnaire. The respondents are BSED major in English 2B and Science 2 majority are females, their parents' highest educational attainment finished Secondary Graduates have less than P11,690, monthly tuition and consist of 4 to 6 members. Findings revealed that employability, financial status, and availability of job are three of the most considered factors in choosing a college course among BSED English and Science students. It is also concluded that the factors affecting the course preference among students are less extent and that there are no significant differences on the course preference among respondents along all its demographic profile of the students. It is hereby recommended that students must have a clear understanding of what they really wanted in the future before choosing a course in college.",
#   'keyword': 'education, course preference, students',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 9, 58),
#   'archive_date': None},
#  {'article_id': 17,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': "Stakeholders' Hands-on Assistance in Remote Learning Engagement: Addressing Challenges in Modular Distance Learning",
#   'author': 'Dr. Dennis M. Marquez',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "In response to the educational challenges brought by the pandemic, the Las Piñas National High School (LPNHS) Almanza initiated a collaborative project dubbed as SHARE (Stakeholders' Hands-on Assistance in Remote Learning Engagement). The effectiveness of Project SHARE in the delivery of educational services through Modular Distance Learning was determined through a mixed-method explanatory research design. This investigation in- volved Grade 7 parents, GPTA officers, teachers, and advisers of Grade 7 learners at LPNHS - Almanza for School Year 2021-2022. The participants were askedto answer a 25-item survey questionnaire (using a 4-point Likert scale which ranged from 1=not satisfied to 4-highly satisfied) about their perceptions on the effectiveness of project SHARE. Focus group discussions with students, teachers, and GPTA officers were conducted to describe further their experiences on modular distance learning. Interviews with parents were likewise conducted to gather feedbacks on their involvement in project SHARE. Quantitative data from the survey were analyzed using descriptive statistics (frequency, mean and standard deviation), while the narrative data were subjected to qualitative data analysis. The results showed that the respondents are highly satisfied with the delivery of educational services in Modular Distance Learning in terms of the distribution and retrieval of Self Learning Modules (Mean= 3.872) and Learning Activity Sheets (Mean=3.876). Respondents were satisfied with the parent-teacher conference and with the aspect of motivating and encouraging learners. Major themes emerged from the FGDs with the respondents like self-approval for learners' development, active partners in terms of education support, and increased community involvement in the aspect of continuing education. Findings revealed that project SHARE has made a significant contribution to the intrinsic and extrinsic motivation of students to study in spite of the COVID-19 epidemic. Furthermore, project SHARE underscored the positive effects of parents' and teachers' partnership and cooperation regarding the leamers' education, wherein a strong parent-teacher partnership boosts learner achievement. Therefore, schools should have more programs that will encourage parents to be actively involved with their children's education. ",
#   'keyword': "modular distance learning, stakeholders' involvement, remote leaming engagement, parent-teacher partnership",
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 10, 2),
#   'archive_date': None},
#  {'article_id': 18,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Challenges And Opportunities Among School Administrators In the Implementation of Blended Learning',
#   'author': 'Jenelyn G. Sabellina, Bazil T. Sabacajan, Macario B. Oclarit, Edgardo V. Abanil',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': 'School administrators encountered different challenges in the implementation of blended learning. Hence, this study aimed to assess the extent of challenges encountered among school administrators, and to determine the opportunities. The study used mixed-method utilizing both the quantitative and qualitative method of data collection. The quantitative method was done through survey questionnaire, while qualitative method was done in the form of focus group discussions. There are fifty-three (53) school administrators as respondents in the study. Findings revealed that school administrators encountered challenges in high extent. The findings also revealed that there were four themes mentioned by the school administrators, these include, access, openness to change, strong linkages and parental involvement. Despite the different challenges encountered by the school administrators in the implementation of blended learning, they still strive to overcome and cope with the challenges.',
#   'keyword': 'administrators, blended learning, challenges, opportunities',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 10, 9),
#   'archive_date': None},
#  {'article_id': 19,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Research Capability of Faculty of Arts and Sciences in a Local University: Basis for a Proposed Training Program',
#   'author': 'Mercado, Joseph Santos, Nenita De Leon, Jose Huertas, Jennelyn Catu, Rosalie Corsame, Bernadette Fortuno, Pamela',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': "The study sought to determine the readiness of Universidad De Manila's College of Arts and Science faculty when it comes to conducting research. Using the descriptive quantitative method, self-made questionnaires were distributed to twenty-eight faculty members, most of whom are female married Instructors with MA/MS degrees. Results revealed that although the faculty members have responded that they are very much capable of researching because of the encouragement from the school head and support from colleagues, most of them have responded they are only capable when it comes to having access to the internet, books, and sample research, having a culture of action research in the university, and easily finishing a study. The overall rating for all the indicators was also capable according to the instructors, assistant professors, and full professors, except for associate professors who assessed themselves as very capable.",
#   'keyword': 'research, technology, higher education institution',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 10, 16),
#   'archive_date': None},
#  {'article_id': 20,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'The Perspectives and Preferences of BSIT Students at Quezon City University in Online Learning',
#   'author': 'Paula Joy L. Dela Cruz, Christian B. Escoto, Dr. Isagani M. Tano',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': 'The pandemic due to covid-19 virus has huge impact in the academic community. Many colleges, instructors, and students at all levels have been affected by the inability to move quickly to electronic and online learning environments. The number of colleges and universities offering distance education programs increased significantly around the world, and distance education has exploded in many countries. According to Mykhaylova (2021), the crisis has affected more than 1.37 billion students. Students have been forced to move from physical college campuses and adapt to modern online educational environments as a result of the advantages and disadvantages. They experienced anxiety, isolation, and confu- sion about what will happen with their classes, tests, graduation, and other significant events affecting their academic course, such as platform usability problems, despite possible Covid- 19 virus health risks. However, the hassle of commuting to school has been eliminated, and having the freedom to learn anytime and having enough rest and sleep has been possible, as well as keeping safe at home from the Covid-19 virus. Traditionally, edu- cators used distance learning to incorporate various learning methods into their lesson plans. The Covid-19 pandemic has made online learning mandatory, pushing schools and universities to quickly implement unprecedented strategies in their attempts to make distance education accessible, including creating an immediate learning environment in a setting that is distinct from conventional classrooms. Therefore, the researchers would like to determine the perspective of BSIT students on online learning based on their experience during its implementation and also identify their preferences. To help Quezon City University take action for better management of facilitating online classes. Since computers and technology are already part of the BSIT students; selected program at Quezon City University, the researchers also determined the impact of online learning to them using, as well as its advantages and disadvantages.',
#   'keyword': '',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 10, 38),
#   'archive_date': None},
#  {'article_id': 21,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Designing a Hybrid Curriculum on Diploma in Construction Design and Technology Innovation: An Industry-based Competency Learning-Career Pathway Model',
#   'author': 'Dr. Rene M. Colocar, Ma. Arra B. Santos',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': 'The demand for 3D designers and 3D modelers has been consistently increasing in different industry sectors such as construction, manufacturing and Information Technology and creative industry. In this view, the Marikina Polytechnic College aims to design and develop a hybrid curriculum that could provide basic to advance skills in technical drafting technology with focus in construction industry. The curriculum is hybrid in terms of its framework, content and pedagogy, learning environment and modality, and assessment. The hybrid curriculum incorporates the TVET and CHED framework by following the Philippine Qualification Framework (PQF). It aims to provide a learning pathway for beginners and professionals who would like to pursue technical skills and professional development in architectural design, graphics and visual techniques and advanced building information mod- elling. This would provide an opportunity for learners to receive certification and qualification for competencies gained per course which is recognized by government institutions and private companies. Through series of planning and consultations, the Diploma in Construction Design and Technology Innovation program is developed and evaluated for implementation. The development process of the hybrid curriculum is a multi-phase and cyclical process which started from March 2021 to August 2022. This includes planning with the technical working committee; identifying key issues and trends in construction industry; assessing needs and issues; defining the diploma program coals and course objectives; curriculum mapping; and developing assessment instruments. This would serve as venue to provide flexible learning pathway to learners from diploma to higher education degree programs.',
#   'keyword': 'curriculum design and development, Philippine qualifications framework, hybrid diploma program, developmental research, Philippines',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 10, 42),
#   'archive_date': None},
#  {'article_id': 22,
#   'author_id': 1,
#   'journal_id': 2,
#   'issues_id': 1,
#   'title': 'Tarlac State University Bilang Espasyo at Mekanismo ng Multikulturalismo at Pagsasabansa',
#   'author': 'Jeanette M. Baquing, PhD',
#   'volume': 'Volume 1',
#   'privacy': 0,
#   'date': 'March 2023',
#   'abstract': 'Tarlac State University (TSU) is a multi-ethnic and multicultural institution with a student population that is predominated by the Kapampangan, Ilocano, and Tagalog ethnolinguistic groups. This paper is a comparative study of ethnic and national stereotypes and self-stereotypes of these three ethnolinguistic groups. Using a modified Katz and Braly trait checklist, as well as their uniformity index, this paper was able to: 1) determine the ethnic stereotypes of the said ethnolinguistic groups; 2) compare and contrast the uniformity as well as positivity of the three ethnic stereotypes; 3) determine the ethnic self-stereotypes of the same ethnolinguistic groups; 4) compare and contrast the uniformity as well as positivity of the three ethnic stereotypes with their corresponding ethnic self- stereotypes; 5) determine the national self-stereotypes of the three ethnolinguistic groups; and 6) compare and contrast the uniformity as well as positivity of the three national self-stereotypes with their corresponding ethnic self-stereotypes. This paper is significant in understanding the peaceful and productive co-existence of the said three ethnolinguistic groups not only in TSU but also in Tarlac City, and Tarlac Province. This paper is also significant in exploring how multi-ethnicity and multicultural condition may contribute towards imagining national identity and building the nation.',
#   'keyword': 'Tarlac State University, Philippine Ethnolinguistic groups, ethnic stereotypes, national stereotype, national self-stereotype',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 23, 22, 10, 45),
#   'archive_date': None},
# ...
#   'keyword': 'veggy burger, eggplant, vegetarian, healthy, innovative',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 15, 7, 33, 55),
#   'archive_date': None},
#  {'article_id': 172,
#   'author_id': 1,
#   'journal_id': 3,
#   'issues_id': 2,
#   'title': 'THE INNOVATION MOTORCYCLE HELMET BAG WITH THEFT PREVENTION FEATURES, WATER-RESISTANT FABRIC, AND ALARM SENSOR',
#   'author': 'Oscar Jevilliy R.Sabillo, Clarilyn Mae R. Dichoso, Carolyn Deocales, Arfel C. Canencia, Raniel B. Taripe, Sharmaine M. Avila',
#   'volume': '',
#   'privacy': 0,
#   'date': '',
#   'abstract': 'IE Solutions aim to develop a research and development that will have a significant influence on\r\nsociety and continual support for the growing generation\'s new ideas. The start-up think that the\r\ninnovative ideas may address the community\'s problems. The company also aims to offer solutions for a\r\nbrighter future, aspires to assist the community in alleviating the issues that we are now facing by\r\nproviding a simple yet effective option. The company welcomes students who seek to contribute to the\r\nfield of engineering and technology are the driving force behind this movement. That said, IE Solution is\r\nhere to help with the solution.\r\nThe proponents decided to introduce Innovative Helmet Bag to the local market, which can alleviate the\r\nissues and worries of motorcycle riders from losing their helmet in public place to getting wet on the\r\ninterior of their helmet. Based from the results in our research instrument through survey, the\r\nrespondents who answered yes to the question "Are you willing to buy a helmet bag that has anti-theft\r\nprevention, water resistant feature, and alarm sensor?" got a frequency of 383 or 99% from the 385 total\r\nrespondents. Therefore, the market acceptability is 99%. This study findings resulted that a majority of\r\nmotorcycle drivers are worried about their Helmet bag being stolen and having wet from its interior part.\r\nThe issues mentioned above plays an important role in the increased status of registered motorcycle\r\naround NCR. This means there is possibility of having a good demand for Innovative Helmet Bag for the\r\nstart-up company.',
#   'keyword': 'Innovative, Adaptable, Reliable, Comfortability, Helpful',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 15, 7, 33, 55),
#   'archive_date': None},
#  {'article_id': 173,
#   'author_id': 1,
#   'journal_id': 3,
#   'issues_id': 2,
#   'title': 'URSHADIE: PRODUCTION OF WEATHERPROOF PHONE SHADE FOR REGISTERED MOTORCYCLE RIDERS IN NCR EAST',
#   'author': 'Venacio L. Uy III, Jerico D. Zamora, Jomar C. Cascabel, Maulana B. Dicalingun, Nickie Ace D. Delfin, Raniel B. Taripe, Leonard A. Catchillar',
#   'volume': '',
#   'privacy': 0,
#   'date': '',
#   'abstract': "This study explores the problems encountered by NCR-East's registered motorcycle riders when using their mobile phones under erratic weather conditions. The URS Company conducted a survey on\nwhat phone protector are already existing in the market and are commonly used by registered motorcycle riders in NCR-East. Also, the company asked the respondents how their mobile phones are protected by the product that they are currently using. From the information gathered and brainstorming occurred, the URS company came up with a product design that satisfies the needs of the user when it comes to the protection of their mobile phones while driving. URShadIE Portable Safety Shade is an accessory that protects the rider's phone against\nerratic weather conditions. The safety shade has a leather case with a water-resistant zipper that serves\nas protection from the rain. Also, it has an anti-glare roof in order to make the phone more accessible\neven under the sun. This product is attached to their phone holder that is mounted to their motorcycle's\nhandlebar.\nWith the help of the URShadIE Portable Safety Shade, the rider will feel more comfortable while\ndriving. They can also ensure the quality of this product. The objective of this product is to make the\nphone accessible and easy to use in any kind of weather condition; whether it is for navigation,\nanswering calls, receiving and/or delivering orders without even removing the mobile phone from its\nholder.",
#   'keyword': 'Portable, Erratic, Accessible, Water-resistant, Anti-glare',
#   'references': '',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 1',
#   'workflow': '#navs-top-submission',
#   'article_support': None,
#   'date_added': datetime.datetime(2023, 11, 10, 8, 0),
#   'publication_date': datetime.datetime(2023, 11, 15, 7, 33, 55),
#   'archive_date': None},
#  {'article_id': 174,
#   'author_id': 164,
#   'journal_id': 1,
#   'issues_id': 3,
#   'title': 'Action Research on Determining the Effectiveness of Distribution of Laptop and Pocket Wifi in Quezon City University in Response to the New Normal',
#   'author': 'Fatima',
#   'volume': 'Volume 1',
#   'privacy': 1,
#   'date': '2023-03-01',
#   'abstract': "As the global community grapples with the far-reaching impacts of the COVID-19 pandemic, this research explores the effectiveness of the distance learning response undertaken by Quezon City University (QCU) in collaboration with the Quezon City (QC) Government. The study aims to evaluate the distribution of laptops and pocket Wi-Fi devices as critical components of QCU's strategy to adapt to the new normal in education. Amidst the challenges posed by the pandemic, QCU successfully procured 8,000 laptops and provided monthly internet allowances, demonstrating its commitment to facilitating remote learning. However, the study reveals that the distribution faced obstacles, resulting in 4,358 laptops reaching students by March 2021. Survey data collected from 5,893 QCU students sheds light on the reasons behind the low turnout, with 2,814 students opting not to borrow laptops. Notably, the study identifies various challenges faced by students in the transition to online learning, including unstable internet connections, lack of conducive study environments, and distractions from social media. The findings indicate that while the majority of students benefitted positively from the provided laptops, challenges persist. Respondents expressed a desire to return to face-to-face learning, emphasizing the importance of stable internet connectivity. To address these concerns, the QC Government allocated 5,225 pocket Wi-Fi units to ensure continuous interactions among students and teachers. Recommendations include comprehensive research and planning, a gradual transition to blended learning, additional equipment provisioning, and ongoing orientation and training programs.\xa0",
#   'keyword': 'accuracy payment,work productivity,social isolation,faculty portal,stress',
#   'references': 'ABS-CBN News. (2020). Topic page on philippines-coronavirus: ABS-CBN News. ABS- CBN News. https://news.abs-cbn.com/list/tag/philippines-coronavirus. Accessed 18 Dec 2020.Baccay, O.T. (2020). CHED encourages SUCS to adopt flexible learning mode. Philippine Information Agency. Available at https://pia.gov.ph/news/articles/1042458Betz, A. Homeschool vs Distance Learning from https://www.educationcorner.com/ homeschool-vs-distance-learning.htmlCahapay, M.B. (2020). Rethinking education in the new normal post-COVID-19 era: A curriculum studies perspective. Aquademia, 4(2). https://doi.org/10.29333/ aquademia/8315Galvez, D. (2020). QC gov\'t to distribute 3,210 laptops to teachers for online classes. Inquirer.Net. Available at https://newsinfo.inquirer.net/1343976/qc-govt-to-distribute -3210-laptops-to-teachers-for-online-classesGMA NEWS ONLINE (2020, August 18). Manila to start distribution of tablets, laptos to students teachers next week from https://www.gmanetwork.com/news/news/ metro/751777/manila-to-start-distribution-of tablet-laptops-to-students-teachers-next-week/story/Knowles, J.G., Marlow,S.E. and Muchmore J.A. (1992). From Pedagogy to Ideology: Origins and Phases of Home Education in the United States, 1970-1990. The University of Chicago Press Journals, American Journal of Education, Volume 100, Number 2 fromhttps://www.journals.uchicago.edu/doi/abs/10.1086/444014Malaya, B. (2020 August 05) DepEd Distance Learning:Here\'s what you need to know fromhttps://www.whatalife.ph/deped-distance-learning-heres-what-you-need-to-know/Manila Public Information Office (2020, August 17). from https://www.facebook.com/ ManilaPIO/posts/929670647517625Mateo, J.(2020, June 13). "Homeschooling an option, but it\'s not for all" from https:// www.philstar.com/headlines/2020/06/13/2020565/homeschooling-option-its-not-all Oducado, R.M.F. (2019). Gen Z nursing students\' usage, perception and satisfaction with Facebook for educational purposes: Tool for learning or distraction. Indonesian Nursing Journal of Education and Clinic, 4(1), 79-89. http://dx.doi.org/10.24990/ injec.v4i1.241Official Gazette of the Republic of the Philippines (2014, December 09). Republic Act No. 10650 from https://www.officialgazette.gov.ph/2014/12/09/republic-act-no-10650Pastor C.K.L. Sentiment analysis on synchronous online delivery of instruction due to extreme community quarantine in the Philippines caused by Covid-19 pandemic. Asian J. Multi. Stud. 2020;3(1):1-6. [Google Scholar]Pedrajas, J. (2020, November 25). Caloocan City gov\'t distribution tablets to students fromhttps://www.mb.com.ph/2020/11/25/caloocan-govt-distribution-of-tablets-to studentsPhilippine Department of Health. (2020). Updates on Covid-19. Available at https:// covid19.healthpilipinas.ph/updates-covid',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 2',
#   'workflow': '#navs-top-production',
#   'article_support': None,
#   'date_added': datetime.datetime(2024, 3, 7, 15, 0, 57),
#   'publication_date': datetime.datetime(2024, 3, 7, 16, 24, 49),
#   'archive_date': None},
#  {'article_id': 177,
#   'author_id': 221,
#   'journal_id': 1,
#   'issues_id': 3,
#   'title': 'The Relationship Between Activism and Select Brand Performance Metrics: The Cases of C2 Green Tea and Lucky Me! Pancit Canton',
#   'author': 'Juan',
#   'volume': 'Volume 1',
#   'privacy': 1,
#   'date': '2023-03-01',
#   'abstract': 'This paper determines the statistical relationship of brand activism on Facebook to the respective brand image, purchase intent, likelihood to shift, degree of interest, and recommendation toward C2 Green Tea and Lucky Me! Instant Pancit Canton. Brand activism is a way for companies to express their opinions and values on social, a, or political issues that matter to them and their customers. The gathering of respondents was done in purposive way who were who are from different age groups, socio-economic classes, and regions. The researcher conducted a Pearson Product-Moment Correlation Analysis to measure the statistical association of brand activism on Facebook with various dependent variables. This is a statistical technique that assesses the strength and direction of the linear relationship between two continuous variables. The analysis showed that only brand image and interest level were the independent variables that had a strong positive correlation with the importance of brand activism on Facebook (dependent variable). No significant differences were observed between the responses for C2 Green Tea and Lucky Me! Instant Pancit Canton. This paper advances the general knowledge of brand activism in the Philippine context. It provides practical implications for marketers and advertisers who want to utilize social media platforms to engage with their consumers on relevant social, environmental, or political issues.',
#   'keyword': 'brand activism,correlation,brand image,purchase intent',
#   'references': 'Gray, A. (2019). "Brands Take a Stand for Good: The Effect of Brand Activism on Social Media Engagement". Honors Theses and Capstones. https://scholars.unh.edu/ honors/440 Inquirer.net (2020, July 18). All things instant capture Filipinos\' fancy.Thquirernet. https://businessinquirer.net/302749/all-things-instant-capture-filipinos-fancy Key T. et al. (2021). Brand activism change agents: strategic storytelling for impact and authenticity. Journal of Strategic Marketing. 001:10.1080/0965254X.2021.1904435 Kumar, N. (2020). Study the Impact of Brand Activism and Political Activism on Marketing Trends. European Journal of Molecular & Clinical medicine Licsi, A. (2022, April 20). \'No need to withdraw\': Here\'s how brands put their own spin On the controversial withdrawal callout. The Philippine Star. https://philstarlife.com/ news-and-views/893881-brands-own-spin-on-controversial-withdraw-call?page=S Manfredi-Sanchez, J.L. (2019). Brand activism. Communication & Society. https:// dolorg/10.15581/003.32.4.343-359 Milfeld, \'land Flint, D.J. (2020). When brands take a stand: the nature of consumers\' polarized reactions to social narrative videos. Journal of Product & Brand Management. https://dolorg/10.1108/JPBM-10-2019-2606 Mukherjee S. (2018). Brand activism: Does courting controversy help or hurt a brand?. Intl Journal of Research in Marketing. https://doi.org/10.1016/j.ijresmar.2020.02.008 Shetty A. et al. (2019). Brand activism and millennials: an empirical investigation into the perception of millennials towards brand activism. Problems and Perspectives in Management. DOI: 10.21911/00m.17(4).2019.14 Sibai, 0. et al. (2021). Authenticating brand activism: Negotiating the boundaries of free Speech to make a change. Psycho! Mork. https://doi.org/10.1002/mar.21477 Tulshyan, R. (2013). This Amazing Hair Commercial Portrays Gender Labels Effectively. Forbes.https://www.forbes.com/sitestruchikatulshyan/2013/12/06/this amazing-hair commercial-portrays-sexist-labels/?sh=2f84707f48cf Whitler. K. and Pohl. M. (2021). Brand Purpose. Darden Case No. UVA-M-1016. https://ssrn.com/abstract=3942697 Vredenburg. J. et al. (2020). Brands Taking a Stand: Authentic Brand Activism or Woke Washing?. Journal of Public Policy & Marketing. https:// doi.org/10.1177/0743915620947359 Business Mirror: (2018, March 20). Enjoy your favorite C2 Green Tea with a refreshing new look. Business Mirror.  https://businessmirror.com.ph/2018/03/20 eniov-vour-favorite-c2-green-tea-with-a-refreshing-new-look/ Champlin. S. et al. (2019). How brand-cause fit shapes real-world advertising messages: a qualitative exploration of \'femvertising\'. International Journal of Advertising. DOI: 10.1080/02650487.2019.1615294 Fuentes, A. (2022, August 10). Monde Nissin net income down in first half; sees July drop in noodle s ales over scare. ABS-CBN News. https://news.abs cbn.com/ business/08/10/22/lucky-me-maker-sees-15-pct-d rop-in-july- sales-over-noodle-Scare Get the Real Philippines. (2020, April 5). Ligo Sardines VP ops learns the hard way: Go woke, go BROKE. Get Real Post. https://www.getrealphilippines.com /2020/04/lig0- sardines- ligo-vp-ops-mikko-lawrence-tung-learns-the-hard-way-cio-woke-go-broke/ Gobs G. (2016, July 5). In the Philippines, the mobile carrier makes a call for LGBT pride. Campaign Live. https://www.campaignlive.com/article/philippines-mobile-carrier-makes-call-lqbt- pride/1401379  ',
#   'comment': '',
#   'content': '-',
#   'status': '1',
#   'round': 'Round 3',
#   'workflow': '#navs-top-production',
#   'article_support': None,
#   'date_added': datetime.datetime(2024, 3, 8, 13, 42, 39),
#   'publication_date': datetime.datetime(2024, 3, 9, 5, 34, 51),
#   'archive_date': None}]

# %%
id = [row['article_id'] for row in data]
overviews = [row['abstract'] for row in data]
titles = [row['title'] for row in data]

# %%
for n, name in enumerate(overviews):
    temp = name.lower().split(" ")
    temp = [''.join([letter for letter in word if letter.isalnum()]) for word in temp]
    temp = [word for word in temp if word not in stop_words]
    temp = ' '.join(temp)
    overviews[n] = temp
    
for n, title in enumerate(titles):
    temp = title.lower().split(" ")
    temp = [''.join([letter for letter in word if letter.isalnum()]) for word in temp]
    temp = [word for word in temp if word not in stop_words]
    temp = ' '.join(temp)
    titles[n] = temp

# %% [markdown]
# ## Cosine Similarity

# %%
# Calculate cosine similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
def get_reviewer_recommendation(input_article):

    sql_query = f'''
        SELECT * FROM author
    '''
    
    db.ping(reconnect=True)
    with db.cursor() as cursor:
        cursor.execute(sql_query)
        data = cursor.fetchall()
        
    # newIds = [row['article_id'] for row in datas]
    # newOverviews = [row['abstract'] for row in datas]
    # newTitles = [row['title'] for row in datas]
    ids = [row['author_id'] for row in data]
    field_of_expertises = [row['field_of_expertise'] for row in data]
    bios = [row['bio'] for row in data] 

    # print(len(newIds))
    # for i in newIds:
    #     print(i)

    
    modified_bios = []
    
    for n, bio in enumerate(bios):
        if bio is None:
            modified_bios.append("")
            continue
        temp = bio.lower().split(" ")
        temp = [''.join([letter for letter in word if letter.isalnum()]) for word in temp]
        temp = [word for word in temp if word not in stop_words]
        temp = ' '.join(temp)
        modified_bios.append(temp)
        
    modified_field_of_expertises = []

    for n, field_of_expertise in enumerate(field_of_expertises):
        if field_of_expertise is None:
            modified_field_of_expertises.append("")
            continue
        parts = field_of_expertise.strip().split(",")
        processed_parts = []
        for part in parts:
            words = part.lower().strip().split() 
            processed_part = " ".join(word for word in words if word not in stop_words) 
            processed_parts.append(processed_part)
        modified_field_of_expertises.append(" ".join(processed_parts)) 
        
    
    # Joining the data
    joined_data = [field_of_expertise + " " + bio if bio is not None else None for field_of_expertise, bio in zip(modified_field_of_expertises, modified_bios)]

    # Preprocess input_article
    input_article = input_article.lower().strip().split(" ")
    input_article = [''.join([letter for letter in word if letter.isalnum()]) for word in input_article]
    input_article = [word for word in input_article if word not in stop_words]
    input_article = ' '.join(input_article)
    joined_data.append(input_article)

    # Vectorization
    vectorizer = CountVectorizer().fit(joined_data)
    vectorized_data = vectorizer.transform(joined_data).toarray()

    # Compute cosine similarity
    cosine_sim_words = cosine_similarity(vectorized_data, vectorized_data)

    # Sort similar words
    similar_words = sorted(enumerate(cosine_sim_words[-1]), key=lambda x: x[1], reverse=True)

    recommended_articles = []

    # Iterate over similar words
    for i, similarity_score in similar_words:
        if i < len(joined_data) - 1:  
            recommended_article = {key: data[i][key] for key in data[i]}
            recommended_article['score'] = similarity_score
            recommended_articles.append(recommended_article)

    return recommended_articles

# %%
get_reviewer_recommendation("An information-analytical software has been developed for creating digital models of structures of porous materials. The information-analytical software allows you to select a model that accurately reproduces structures of porous materials—aerogels—creating a digital model by which you can predict their properties. In add")
# Out:
# [{'author_id': 174,
#   'journal_id': None,
#   'first_name': 'Claire',
#   'last_name': 'Jacob',
#   'middle_name': 'Samson',
#   'public_name': None,
#   'email': 'clairekaye.jacob18@gmail.com',
#   'email_verified': 'clairekaye.jacob18@gmail.com',
#   'password': '7b1c3024f98bff03edb36591f7f70ed3dae852ac8826b8ffbe9b54b006175210',
#   'gender': 'Female',
#   'birth_date': datetime.date(2001, 11, 18),
#   'phone_number': '',
#   'afiliations': 'COLLEGE OF COMPUTER STUDIES',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Networking, Programming, Software Tools',
#   'bio': "I'm Claire, a tech-driven student skilled in programming, networking, and digital design. With experience in diff. coding languages & tools like CPT, I'm eager to tackle real-world challenges and become a leader in technology.",
#   'orc_id': '0009-0007-0892-2033',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': '../Files/uploaded-profile/journal profile.jpg',
#   'score': 0.1111111111111111},
#  {'author_id': 1,
#   'journal_id': 1,
#   'first_name': 'QCU',
#   'last_name': 'Journal',
#   'middle_name': '',
#   'public_name': None,
#   'email': 'qcujournalexample@gmail.com',
#   'email_verified': 'qcujournalexample@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': '',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': None,
#   'position': 'FACULTY',
#   'country': None,
#   'school_name': '',
#   'field_of_expertise': '',
#   'bio': None,
#   'orc_id': '',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 1, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 159,
#   'journal_id': None,
#   'first_name': 'Eloisa Marie',
#   'last_name': 'Baylon',
#   'middle_name': 'Maglana',
#   'public_name': None,
#   'email': 'eloisamariebaylon@gmail.com',
#   'email_verified': 'eloisamariebaylon@gmail.com',
#   'password': 'dc59ff69ba37853ebe3cd04c30db24dc6a55344fa1665317c4413587248222b1',
#   'gender': 'Female',
#   'birth_date': datetime.date(1948, 1, 7),
#   'phone_number': '+639551626672',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'Web Development',
#   'bio': '',
#   'orc_id': '0009-0003-9088-8268',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 2, 22, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/423539900_355183254071354_4981676414683112915_n.jpg',
#   'score': 0.0},
#  {'author_id': 160,
#   'journal_id': None,
#   'first_name': 'Mon Cedric',
#   'last_name': 'Avila',
#   'middle_name': 'Orbeta',
#   'public_name': None,
#   'email': 'avilamon0123@gmail.com',
#   'email_verified': 'avilamon0123@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': 'Male',
#   'birth_date': datetime.date(2001, 11, 24),
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'Web Development',
#   'bio': '',
#   'orc_id': '0009-0005-4489-9198',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 2, 22, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': '../Files/uploaded-profile/Avila, Mon Cedric O..jpg',
#   'score': 0.0},
#  {'author_id': 161,
#   'journal_id': None,
#   'first_name': 'Mavis',
#   'last_name': 'Vermillion',
#   'middle_name': 'Teach',
#   'public_name': None,
#   'email': 'jhexphel16@gmail.com',
#   'email_verified': 'jhexphel16@gmail.com',
#   'password': 'd07e7c4cce2afb5fdab874b1f6c1f95a06564921bad3486805e5bd27fad62457',
#   'gender': 'Male',
#   'birth_date': datetime.date(2002, 4, 25),
#   'phone_number': '',
#   'afiliations': 'College of Cooking Pansit Canton',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Web Development',
#   'bio': '“‘Move on.’ Anim na letrang salita. Madaling sabihin, mahirap gawin. Lalo na kung pipilitin mong kalimutan yung taong hanggang ngayon ay mahal mo pa rin.”',
#   'orc_id': '0009-0008-6192-3817',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 23, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/421920839_3681651668783537_2266663650115388377_n.jpg',
#   'score': 0.0},
#  {'author_id': 162,
#   'journal_id': None,
#   'first_name': 'Kimberly',
#   'last_name': 'Pangilinan',
#   'middle_name': 'Buccat',
#   'public_name': None,
#   'email': 'kimberly.pangilinan022@gmail.com',
#   'email_verified': 'kimberly.pangilinan022@gmail.com',
#   'password': '5e946f70f7febdf7a9297b3434e2b54df9b776095128f67a095a3479e768ee7b',
#   'gender': 'Female',
#   'birth_date': datetime.date(2001, 10, 9),
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Education, Professor, Higher Education',
#   'bio': 'Professor in quezon city university major in BS in EducatiaAs a dedicated educator and scholar, Dr. [Your Name] brings a wealth of experience and expertise to the field of education. With a passion for cultivating effective learning environments and foste',
#   'orc_id': '0009-0004-5992-7668',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 23, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '-',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/IMG_20240225_165349.jpg',
#   'score': 0.0},
#  {'author_id': 163,
#   'journal_id': None,
#   'first_name': 'Masterson Kurt',
#   'last_name': 'Malazarte',
#   'middle_name': 'Temporoza',
#   'public_name': None,
#   'email': 'mastersonkurt.malazarte17@gmail.com',
#   'email_verified': 'mastersonkurt.malazarte17@gmail.com',
#   'password': '6cb0aed9b9ce4c120638ba429290bfbbc8e47a2e3c8df0ff88f3f34b1b76e861',
#   'gender': 'Male',
#   'birth_date': datetime.date(2001, 11, 1),
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'sdfsdf',
#   'bio': '...',
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 23, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 164,
#   'journal_id': None,
#   'first_name': 'Fatima',
#   'last_name': 'Jacinto',
#   'middle_name': 'Caliboso',
#   'public_name': None,
#   'email': 'jacintofatimamae@gmail.com',
#   'email_verified': 'jacintofatimamae@gmail.com',
#   'password': '76b87dd7eeba8bb39864056fdd1ed5566f89e5de79ee84409e3e06756b7a280a',
#   'gender': 'Female',
#   'birth_date': datetime.date(2002, 7, 23),
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'Web Development, IT',
#   'bio': 'BSIT ',
#   'orc_id': '0009-0008-6192-3002',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 2, 23, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'Student',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/images (33).jpeg',
#   'score': 0.0},
#  {'author_id': 166,
#   'journal_id': None,
#   'first_name': 'Arnel',
#   'last_name': 'Mosenabre',
#   'middle_name': '',
#   'public_name': None,
#   'email': 'arnel.mosenabre05@gmail.com',
#   'email_verified': 'arnel.mosenabre05@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': 'Male',
#   'birth_date': datetime.date(2024, 2, 23),
#   'phone_number': '09745834774',
#   'afiliations': 'Student',
#   'position': 'STUDENT',
#   'country': 'United States',
#   'school_name': 'QCU',
#   'field_of_expertise': 'IT DEV',
#   'bio': 'I am me',
#   'orc_id': '0009-0002-3848-7283',
#   'url_orc_id': 'facebook,.com',
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Admin',
#   'marital_status': '',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': ' ',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 167,
#   'journal_id': None,
#   'first_name': 'Raven',
#   'last_name': 'Cuagon',
#   'middle_name': 'Gabatbat',
#   'public_name': None,
#   'email': 'revean.gabatbat.cuagon@gmail.com',
#   'email_verified': 'revean.gabatbat.cuagon@gmail.com',
#   'password': '21d776e96e55557619b3d6f6a91526566e1220d71dbeb128ff3c8e7fc601644f',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': 'N/A',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': 'Maginoo pero medyo bastos',
#   'orc_id': '0009-0001-1243-1014',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 168,
#   'journal_id': None,
#   'first_name': 'Richmonde',
#   'last_name': 'Ayag',
#   'middle_name': 'Magyaya',
#   'public_name': None,
#   'email': 'richmonde.ayag002@gmail.com',
#   'email_verified': 'richmonde.ayag002@gmail.com',
#   'password': '36a857358b65748c6d0102d54e33c9aad7d71820fd03512541f9d25fc2ff5c4e',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': '',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 169,
#   'journal_id': None,
#   'first_name': 'Johncel',
#   'last_name': 'Lamberte',
#   'middle_name': 'Casipong',
#   'public_name': None,
#   'email': 'johncel.lamberte14@gmail.com',
#   'email_verified': 'johncel.lamberte14@gmail.com',
#   'password': '163d35c26f0e52d59a9500e25213b2b9f3c7a01a48d2c4920184dc34a95a8a1f',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': '',
#   'position': 'STUDENT',
#   'country': 'Cyprus',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '0009-0001-4915-2115',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Admin',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 170,
#   'journal_id': None,
#   'first_name': 'Neil Justin',
#   'last_name': 'Nalam',
#   'middle_name': 'Pahunang',
#   'public_name': None,
#   'email': 'justinpahunang@gmail.com',
#   'email_verified': 'justinpahunang@gmail.com',
#   'password': '715f1fde9659150caa50894ef5a9ecdf09ae7391a06287bb8129e2e065d17d8a',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': '',
#   'position': 'STUDENT',
#   'country': 'Cyprus',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 173,
#   'journal_id': None,
#   'first_name': 'Quenie Elaiza',
#   'last_name': 'Narisma',
#   'middle_name': 'Paylangco',
#   'public_name': None,
#   'email': 'quenieelaiza.narisma08@gmail.com',
#   'email_verified': 'quenieelaiza.narisma08@gmail.com',
#   'password': 'd7e0410a561dd187d4fb4a52ef05beba8c36216d08614420050db84b1fe35022',
#   'gender': 'Female',
#   'birth_date': datetime.date(2002, 2, 8),
#   'phone_number': '',
#   'afiliations': 'Kkk',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': '',
#   'bio': 'Student ',
#   'orc_id': '0009-0000-8302-1517',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 2, 24, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 175,
#   'journal_id': None,
#   'first_name': 'Raven',
#   'last_name': 'Cuagon',
#   'middle_name': 'Gabatbat',
#   'public_name': None,
#   'email': 'Arbeh420@gmail.com',
#   'email_verified': 'Arbeh420@gmail.com',
#   'password': '21d776e96e55557619b3d6f6a91526566e1220d71dbeb128ff3c8e7fc601644f',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': 'STUDENT',
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 176,
#   'journal_id': None,
#   'first_name': 'Maricar',
#   'last_name': 'Noel',
#   'middle_name': 'David',
#   'public_name': None,
#   'email': 'maricarnoel04@gmail.com',
#   'email_verified': 'maricarnoel04@gmail.com',
#   'password': 'ca4c77e84e046d363fa9fc125be39cd89936b46c340ba1daad7acf07d2f7df43',
#   'gender': 'Female',
#   'birth_date': datetime.date(2003, 10, 4),
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Canada',
#   'school_name': None,
#   'field_of_expertise': 'computer hardware',
#   'bio': '',
#   'orc_id': '0009-0003-1952-7208',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Married',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': 0,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 177,
#   'journal_id': None,
#   'first_name': 'Daphine',
#   'last_name': 'Agustin',
#   'middle_name': 'Arisgado',
#   'public_name': None,
#   'email': 'agustindaph@gmail.com',
#   'email_verified': 'agustindaph@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': 'Female',
#   'birth_date': datetime.date(1995, 11, 25),
#   'phone_number': '',
#   'afiliations': 'Student',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'Computer Hardware',
#   'bio': '“Education is one thing no one can take away from you.” ',
#   'orc_id': '0009-0001-8557-8746',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': ' ',
#   'public_private_profile': 0,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 178,
#   'journal_id': None,
#   'first_name': 'Masterson Kurt',
#   'last_name': 'Malazarte',
#   'middle_name': 'Temporoza',
#   'public_name': None,
#   'email': 'masterson.kurt.malazarte@gmail.com',
#   'email_verified': None,
#   'password': '691554ac5f0c52332c4d5cc8f0477607782fe8fb3a4bd48066f391c3d5024da8',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 179,
#   'journal_id': None,
#   'first_name': 'Eric Johnes ',
#   'last_name': 'Delos Reyes',
#   'middle_name': 'Alavado ',
#   'public_name': None,
#   'email': 'ericjohnesdelosreyes@gmail.com',
#   'email_verified': 'ericjohnesdelosreyes@gmail.com',
#   'password': '79c00c6d17f2c76e4a755a19a7bc20b830e77fbb528fb12b7bf15b76a9443b5b',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': '',
#   'position': '',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': '',
#   'bio': '',
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 180,
#   'journal_id': None,
#   'first_name': 'Dylan',
#   'last_name': 'Gutierrez',
#   'middle_name': 'Deleon ',
#   'public_name': None,
#   'email': 'dylan.deleon.gutierrez@gmail.com',
#   'email_verified': 'dylan.deleon.gutierrez@gmail.com',
#   'password': 'f7616347f49b8be52ff2e926d5ff4990895c662211d64095e44b8573b5f8d1ba',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': '',
#   'position': '',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '0009-0001-1955-4877',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 181,
#   'journal_id': None,
#   'first_name': 'Ean',
#   'last_name': 'Pingol',
#   'middle_name': 'Velasco',
#   'public_name': None,
#   'email': 'ean.pingol09@gmail.com',
#   'email_verified': 'ean.pingol09@gmail.com',
#   'password': '7be41972eb33b31c2858f630aafe2c360dc9267744058e40b22a26629edfcef6',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': 'Jajaxxd',
#   'position': 'STUDENT',
#   'country': 'Cyprus',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': 'Hajafdd',
#   'orc_id': 'Fdcfdf',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'Hajaj',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 186,
#   'journal_id': None,
#   'first_name': 'Neil Justin',
#   'last_name': 'Nalam',
#   'middle_name': 'Pahunang',
#   'public_name': None,
#   'email': 'neiljustin.nalam05@gmail.com',
#   'email_verified': 'neiljustin.nalam05@gmail.com',
#   'password': '84d955ce81a2b24f2153ea7cef8c949dbfbee6c3352a30b8c4532bbdf9e99990',
#   'gender': 'Male',
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': '',
#   'orc_id': '0009-0009-6125-4251',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 188,
#   'journal_id': None,
#   'first_name': 'Neil Justin',
#   'last_name': 'Nalam',
#   'middle_name': 'Pahunang',
#   'public_name': None,
#   'email': 'neiljustinnalam4@gmail.com',
#   'email_verified': 'neiljustinnalam4@gmail.com',
#   'password': 'ccddfe1abe2c090d190fd4e325891e906a627040874cd47af545e39d54cb8d2d',
#   'gender': 'Male',
#   'birth_date': datetime.date(2002, 9, 5),
#   'phone_number': '',
#   'afiliations': 'College of Computer Studies',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': 'Researcher/ Document',
#   'orc_id': '0009-0009-6125-4251',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 190,
#   'journal_id': None,
#   'first_name': 'Stephen',
#   'last_name': 'Heraldo',
#   'middle_name': 'Suyko',
#   'public_name': None,
#   'email': 'stephenzionheraldo@gmail.com',
#   'email_verified': 'stephenzionheraldo@gmail.com',
#   'password': '2cc4913c4db0b25d78c164dfff232c84960fb532cdf12f871f347c12b4c8c4e2',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Math',
#   'bio': '',
#   'orc_id': '0009-0004-0647-5610',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': '../Files/uploaded-profile/remix-rumble-400x400.jpg',
#   'score': 0.0},
#  {'author_id': 215,
#   'journal_id': 1,
#   'first_name': 'Elyana',
#   'last_name': 'Española',
#   'middle_name': 'Depamallo',
#   'public_name': None,
#   'email': 'elyana.espanola01@gmail.com',
#   'email_verified': 'elyana.espanola01@gmail.com',
#   'password': '5e884898da28047151d0e56f8dc6292773603d0d6aabbdd62a11ef721d1542d8',
#   'gender': 'Female',
#   'birth_date': datetime.date(2002, 1, 1),
#   'phone_number': '09690971146',
#   'afiliations': 'QCU',
#   'position': 'STUDENT',
#   'country': 'Jersey',
#   'school_name': 'Quezon city University',
#   'field_of_expertise': 'Web Developer, UI Designer, IT, Computer',
#   'bio': 'HAHAAHAHHAAHHA',
#   'orc_id': '0009-0007-0600-209X',
#   'url_orc_id': 'https://orcid.org/0009-0007-0600-209X',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 216,
#   'journal_id': None,
#   'first_name': 'Dharren Paul',
#   'last_name': 'Sanchez',
#   'middle_name': '',
#   'public_name': None,
#   'email': 'dharren.sanchez023@gmail.com',
#   'email_verified': 'dharren.sanchez023@gmail.com',
#   'password': 'b548573902e2536732a5dcabde9a5745ed618dd5bd50f8e091e2ec6fd81ac0d6',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': 'QCU',
#   'position': 'STUDENT',
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': 'Developer HAAAAAAAAAAAAAAAAAAAAAAAAAAA',
#   'bio': '',
#   'orc_id': '0009-0003-1767-5960',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': '../Files/uploaded-profile/sanchez.png',
#   'score': 0.0},
#  {'author_id': 219,
#   'journal_id': None,
#   'first_name': 'Ayag',
#   'last_name': 'Ayag',
#   'middle_name': 'Magyaya',
#   'public_name': None,
#   'email': 'hiromiikun40@gmail.com',
#   'email_verified': 'hiromiikun40@gmail.com',
#   'password': '1c6c5efd48c36d921f8be4279266778038c03bf33202fc54d9c5fa97a6528f3b',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0009-0001-5449-5251',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 220,
#   'journal_id': None,
#   'first_name': 'Dylan',
#   'last_name': 'gutierrez',
#   'middle_name': 'deleon ',
#   'public_name': None,
#   'email': 'dylangutz2000@gmail.com',
#   'email_verified': 'dylangutz2000@gmail.com',
#   'password': '4f3d82c6231d74a8fef6627f2d2d83978a23a0544f08fda0cbcd62eec25e2056',
#   'gender': 'Male',
#   'birth_date': datetime.date(2000, 11, 16),
#   'phone_number': '',
#   'afiliations': 'student',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'it',
#   'bio': '',
#   'orc_id': '0009-0001-1955-4577',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 221,
#   'journal_id': None,
#   'first_name': 'Juan',
#   'last_name': 'Dela Cruz',
#   'middle_name': 'Tan',
#   'public_name': None,
#   'email': 'jhexphell@gmail.com',
#   'email_verified': 'jhexphell@gmail.com',
#   'password': 'd07e7c4cce2afb5fdab874b1f6c1f95a06564921bad3486805e5bd27fad62457',
#   'gender': 'Male',
#   'birth_date': datetime.date(2002, 4, 25),
#   'phone_number': '',
#   'afiliations': 'Music Lover',
#   'position': 'STUDENT',
#   'country': None,
#   'school_name': 'Quezon City University',
#   'field_of_expertise': 'Umasa',
#   'bio': '',
#   'orc_id': '0009-0008-6192-3822',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/417544853_746745870739003_243084953764655823_n.jpg',
#   'score': 0.0},
#  {'author_id': 284,
#   'journal_id': None,
#   'first_name': 'Kyle Angeline',
#   'last_name': 'David',
#   'middle_name': 'Ocbeña',
#   'public_name': None,
#   'email': 'kyleangelinedavid27@gmail.com',
#   'email_verified': 'kyleangelinedavid27@gmail.com',
#   'password': '1f55b04b4811898500cc3a1f46c8d35fd2e6c271f21ee6662bf247c31b0e5273',
#   'gender': 'Female',
#   'birth_date': datetime.date(2002, 7, 27),
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': '',
#   'field_of_expertise': 'IT, Computer, Research',
#   'bio': 'Hello World!',
#   'orc_id': '0009-0006-9470-9898',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Admin',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 285,
#   'journal_id': None,
#   'first_name': 'JOHN',
#   'last_name': 'LAMBERTSS',
#   'middle_name': 'CASIPONG',
#   'public_name': None,
#   'email': 'lambertssjohn16@gmail.com',
#   'email_verified': 'lambertssjohn16@gmail.com',
#   'password': '85c98f43b0a6bef14e487bc77da1057b9777630164be065f79ca4cfdd28b8fd9',
#   'gender': 'Male',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Liberia',
#   'school_name': '',
#   'field_of_expertise': ', IT, COMPUTER',
#   'bio': 'HAHA',
#   'orc_id': '0009-0000-0976-8399',
#   'url_orc_id': '',
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 287,
#   'journal_id': None,
#   'first_name': 'Eloisa Marie',
#   'last_name': 'Baylon',
#   'middle_name': 'Maglana',
#   'public_name': None,
#   'email': 'eloisa012816@gmail.com',
#   'email_verified': 'eloisa012816@gmail.com',
#   'password': 'dc59ff69ba37853ebe3cd04c30db24dc6a55344fa1665317c4413587248222b1',
#   'gender': 'Female',
#   'birth_date': datetime.date(1998, 1, 10),
#   'phone_number': '',
#   'afiliations': 'Quezon City University',
#   'position': 'STUDENT',
#   'country': 'Philippines',
#   'school_name': None,
#   'field_of_expertise': 'Information Technology',
#   'bio': '',
#   'orc_id': '0009-0004-0778-2671',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 0,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 288,
#   'journal_id': None,
#   'first_name': 'Raven',
#   'last_name': 'Cuagon',
#   'middle_name': 'G.',
#   'public_name': None,
#   'email': 'arbeh3410@gmail.com',
#   'email_verified': None,
#   'password': '44a3d21b5c44503b9fc88ac83c08ccb7018f31bb046e7b225e150a483a520a0e',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0009-0007-8222-8146',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 290,
#   'journal_id': None,
#   'first_name': 'Allen Jo',
#   'last_name': 'Pascua',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'allenjopascua09@gmail.com',
#   'email_verified': 'allenjopascua09@gmail.com',
#   'password': '182c20340281cff3e42f1e037735dbe9e6228ade413054437dcb4369ab5251a3',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0009-0003-6272-3319',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 291,
#   'journal_id': None,
#   'first_name': 'Fatima ',
#   'last_name': 'Jacinto',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'fatimamaejacinto30@gmail.com',
#   'email_verified': None,
#   'password': '76b87dd7eeba8bb39864056fdd1ed5566f89e5de79ee84409e3e06756b7a280a',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': 'STUDENT',
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0009-0004-6357-2572',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': None,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 293,
#   'journal_id': None,
#   'first_name': 'Kimberly',
#   'last_name': 'Pangilinan',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'kimberly.b.pangilinan@gmail.com',
#   'email_verified': 'kimberly.b.pangilinan@gmail.com',
#   'password': 'b44bfd704c6bfe6a5f122b171b03a8d8d02dd8a8eddff702d3c006ddea986bf2',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0000-0003-2824-785X',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 8, 0, 0),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 294,
#   'journal_id': None,
#   'first_name': 'Angelito',
#   'last_name': 'Bautista Jr',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'angelito.bautista.jr@qcu.edu.ph',
#   'email_verified': 'angelito.bautista.jr@qcu.edu.ph',
#   'password': '5cde0ddf4a8677718dd87a06c511d91fbf8b35446914e3bcb22c738dc4a9528a',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0000-0001-6591-7280',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 10, 13, 37, 23),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 295,
#   'journal_id': None,
#   'first_name': 'Juan',
#   'last_name': 'Dela Cruz',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'jhexphel00@gmail.com',
#   'email_verified': None,
#   'password': 'd07e7c4cce2afb5fdab874b1f6c1f95a06564921bad3486805e5bd27fad62457',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': '0000-0002-1825-0097',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 11, 2, 30, 14),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 297,
#   'journal_id': None,
#   'first_name': 'Gabrielle Louise',
#   'last_name': 'David',
#   'middle_name': 'Ocbena',
#   'public_name': None,
#   'email': 'godavid1@up.edu.ph',
#   'email_verified': 'godavid1@up.edu.ph',
#   'password': 'd859132a547fac714c9c26e72b9da2acee942683818c61befc6eeb6beffc6875',
#   'gender': 'Male',
#   'birth_date': datetime.date(2000, 11, 1),
#   'phone_number': '',
#   'afiliations': 'University of the Philippines',
#   'position': 'Student',
#   'country': 'Qatar',
#   'school_name': None,
#   'field_of_expertise': 'Human Settlement, Ecology, Transportation',
#   'bio': 'Researcher',
#   'orc_id': '0009-0008-0271-517X',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 16, 8, 35, 9),
#   'role': 'Author',
#   'marital_status': 'Single',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': 'N/A',
#   'public_private_profile': 0,
#   'profile_pic': '../Files/uploaded-profile/picture.jpg',
#   'score': 0.0},
#  {'author_id': 300,
#   'journal_id': None,
#   'first_name': 'asda',
#   'last_name': 'asd',
#   'middle_name': None,
#   'public_name': None,
#   'email': 'example@gmail.com',
#   'email_verified': None,
#   'password': 'f8d6fbb6b4e0c42a0cfa76fb9978f1e9d326ba3de720c19a2f55f973a6cde889',
#   'gender': None,
#   'birth_date': None,
#   'phone_number': '',
#   'afiliations': None,
#   'position': None,
#   'country': None,
#   'school_name': None,
#   'field_of_expertise': None,
#   'bio': None,
#   'orc_id': None,
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 17, 2, 37, 4),
#   'role': 'Author',
#   'marital_status': None,
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': None,
#   'public_private_profile': 0,
#   'profile_pic': None,
#   'score': 0.0},
#  {'author_id': 301,
#   'journal_id': None,
#   'first_name': 'Vin',
#   'last_name': 'Marin',
#   'middle_name': '',
#   'public_name': None,
#   'email': 'marvin.gozo23@gmail.com',
#   'email_verified': 'marvin.gozo23@gmail.com',
#   'password': 'f8d6fbb6b4e0c42a0cfa76fb9978f1e9d326ba3de720c19a2f55f973a6cde889',
#   'gender': '',
#   'birth_date': '0000-00-00',
#   'phone_number': '',
#   'afiliations': '',
#   'position': '',
#   'country': 'Cyprus',
#   'school_name': None,
#   'field_of_expertise': 'Math',
#   'bio': '',
#   'orc_id': '',
#   'url_orc_id': None,
#   'date_added': datetime.datetime(2024, 3, 17, 3, 10, 39),
#   'role': 'Author',
#   'marital_status': '',
#   'status': 1,
#   'privacyAgreement': 0,
#   'affix': '',
#   'public_private_profile': 0,
#   'profile_pic': None,
#   'score': 0.0}]

# %%
get_reviewer_recommendation("Education is universally recognized as the answer to socio-economic problems of the world. Hence, course selection is one of many important choices that students will make in determining future plans. It becomes one of the biggest dilemma and challenge in any student's life. Hence, the study sought to investigate the course preference among students. The study used quantitative methods of data collection. The quantitative method was done through a survey questionnaire. The respondents are BSED major in English 2B and Science 2 majority are females, their parents' highest educational attainment finished Secondary Graduates have less than P11,690, monthly tuition and consist of 4 to 6 members. Findings revealed that employability, financial status, and availability of job are three of the most considered factors in choosing a college course among BSED English and Science students. It is also concluded that the factors affecting the course preference among students are less extent and that there are no significant differences on the course preference among respondents along all its demographic profile of the students. It is hereby recommended that students must have a clear understanding of what they really wanted in the future before choosing a course in college.")
# Out:
# [{'author_id': 177,
#   'expertise': 'Computer Hardware',
#   'bio': '“Education is one thing no one can take away from you.” ',
#   'similarity': 0.10380684981717495},
#  {'author_id': 162,
#   'expertise': 'Education, Professor, Higher Education',
#   'bio': 'Professor in quezon city university major in BS in EducatiaAs a dedicated educator and scholar, Dr. [Your Name] brings a wealth of experience and expertise to the field of education. With a passion for cultivating effective learning environments and foste',
#   'similarity': 0.043768810953240846},
#  {'author_id': 284,
#   'expertise': 'IT, Computer, Research',
#   'bio': 'Hello World!',
#   'similarity': 0.032826608214930636},
#  {'author_id': 1, 'expertise': '', 'bio': None, 'similarity': 0.0},
#  {'author_id': 159,
#   'expertise': 'Web Development',
#   'bio': '',
#   'similarity': 0.0},
#  {'author_id': 160,
#   'expertise': 'Web Development',
#   'bio': '',
#   'similarity': 0.0},
#  {'author_id': 161,
#   'expertise': 'Web Development',
#   'bio': '“‘Move on.’ Anim na letrang salita. Madaling sabihin, mahirap gawin. Lalo na kung pipilitin mong kalimutan yung taong hanggang ngayon ay mahal mo pa rin.”',
#   'similarity': 0.0},
#  {'author_id': 163, 'expertise': 'sdfsdf', 'bio': '...', 'similarity': 0.0},
#  {'author_id': 164,
#   'expertise': 'Web Development, IT',
#   'bio': 'BSIT ',
#   'similarity': 0.0},
#  {'author_id': 166,
#   'expertise': 'IT DEV',
#   'bio': 'I am me',
#   'similarity': 0.0},
#  {'author_id': 167,
#   'expertise': None,
#   'bio': 'Maginoo pero medyo bastos',
#   'similarity': 0.0},
#  {'author_id': 168, 'expertise': None, 'bio': '', 'similarity': 0.0},
#  {'author_id': 169, 'expertise': None, 'bio': '', 'similarity': 0.0},
#  {'author_id': 170, 'expertise': None, 'bio': '', 'similarity': 0.0},
#  {'author_id': 173, 'expertise': '', 'bio': 'Student ', 'similarity': 0.0},
#  {'author_id': 174,
#   'expertise': 'Networking, Programming, Software Tools',
#   'bio': "I'm Claire, a tech-driven student skilled in programming, networking, and digital design. With experience in diff. coding languages & tools like CPT, I'm eager to tackle real-world challenges and become a leader in technology.",
#   'similarity': 0.0},
#  {'author_id': 175, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 176,
#   'expertise': 'computer hardware',
#   'bio': '',
#   'similarity': 0.0},
#  {'author_id': 178, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 179, 'expertise': '', 'bio': '', 'similarity': 0.0},
#  {'author_id': 180, 'expertise': None, 'bio': '', 'similarity': 0.0},
#  {'author_id': 181, 'expertise': None, 'bio': 'Hajafdd', 'similarity': 0.0},
#  {'author_id': 186, 'expertise': None, 'bio': '', 'similarity': 0.0},
#  {'author_id': 188,
#   'expertise': None,
#   'bio': 'Researcher/ Document',
#   'similarity': 0.0},
#  {'author_id': 190, 'expertise': 'Math', 'bio': '', 'similarity': 0.0},
#  {'author_id': 215,
#   'expertise': 'Web Developer, UI Designer, IT, Computer',
#   'bio': 'HAHAAHAHHAAHHA',
#   'similarity': 0.0},
#  {'author_id': 216,
#   'expertise': 'Developer HAAAAAAAAAAAAAAAAAAAAAAAAAAA',
#   'bio': '',
#   'similarity': 0.0},
#  {'author_id': 219, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 220, 'expertise': 'it', 'bio': '', 'similarity': 0.0},
#  {'author_id': 221, 'expertise': 'Umasa', 'bio': '', 'similarity': 0.0},
#  {'author_id': 285,
#   'expertise': ', IT, COMPUTER',
#   'bio': 'HAHA',
#   'similarity': 0.0},
#  {'author_id': 287,
#   'expertise': 'Information Technology',
#   'bio': '',
#   'similarity': 0.0},
#  {'author_id': 288, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 290, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 291, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 293, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 294, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 295, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 297,
#   'expertise': 'Human Settlement, Ecology, Transportation',
#   'bio': 'Researcher',
#   'similarity': 0.0},
#  {'author_id': 300, 'expertise': None, 'bio': None, 'similarity': 0.0},
#  {'author_id': 301, 'expertise': 'Math', 'bio': '', 'similarity': 0.0}]
