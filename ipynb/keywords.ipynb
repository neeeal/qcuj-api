# %%
import os
from flask import Flask, request, jsonify
from flask_cors import CORS 
# import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import nltk
import pymysql
import numpy as np
import datetime
import json
from dotenv import load_dotenv

# %%
app = Flask(__name__)
app.json.sort_keys = False
CORS(app) 

db = pymysql.connect(
    host=os.getenv('DATABASE_HOST'),
    user=os.getenv('DATABASE_USER'),
    password=os.getenv('DATABASE_PASSWORD'),
    db=os.getenv('DATABASE_DB'),
    connect_timeout=8800,
    cursorclass=pymysql.cursors.DictCursor
)

nltk.download("stopwords")
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kimbe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sql_query= """
            SELECT 
                keyword
            FROM 
                article 
            # WHERE status = 1
           """
db.ping(reconnect=True)
cursor = db.cursor()
cursor.execute(sql_query)
data = cursor.fetchall()

print(data)
keywords = [row['keyword'] for row in data]
# Out:
# [{'keyword': 'call center representatives, labor productivity, and employment'}, {'keyword': 'social isolation, work satisfaction, stress, work productivity'}, {'keyword': 'electronic wallet, accuracy of payment, on-time delivery, accessibility and efficiency, security and reliability'}, {'keyword': 'Safety of life at sea program (SOLAS), seafarers, MARITIME accidents, risk reduction management program'}, {'keyword': 'access, faculty portal, features, usability, Universidad de manila'}, {'keyword': 'food safety, sanitation, street food, food handling, consumer'}, {'keyword': ''}, {'keyword': 'speaking, video recording, oral communication, integration, online learning'}, {'keyword': 'challenges, online learning, Covid-19 pandemic, laboratory teachers, implementation.'}, {'keyword': 'challenges, online learning, Covid-19 pandemic, laboratory'}, {'keyword': 'challenges, online learning, Covid-19 pandemic, laboratory teachers, implementation'}, {'keyword': 'curriculum enhancement, subject understanding, personal qualities, skill, employability'}, {'keyword': 'academic performance, aviation, PhilSCA'}, {'keyword': 'education, course preference, students'}, {'keyword': "modular distance learning, stakeholders' involvement, remote leaming engagement, parent-teacher partnership"}, {'keyword': 'administrators, blended learning, challenges, opportunities'}, {'keyword': 'research, technology, higher education institution'}, {'keyword': ''}, {'keyword': 'curriculum design and development, Philippine qualifications framework, hybrid diploma program, developmental research, Philippines'}, {'keyword': 'Tarlac State University, Philippine Ethnolinguistic groups, ethnic stereotypes, national stereotype, national self-stereotype'}, {'keyword': 'higher education institution, practices, resilience, strategic actions'}, {'keyword': 'Engineering, training needs analysis, quantitative, QCU'}, {'keyword': 'thesis repository'}, {'keyword': 'Meta-Leadership Model, sequential-explanatory, crisis leadership competency, pandemic response strategy, crisis management plan'}, {'keyword': ''}, {'keyword': 'Test of Homogeneity, cabin fever, pandemic, entrepreneurship education, gender differences'}, {'keyword': 'working students, Covid-19, quantitative research, teleworking, employment'}, {'keyword': 'feeding, meat industry, rabbit, rabbit cage, semi-automatic'}, {'keyword': 'supply chain management, logistics, set-based concurrent engineering'}, {'keyword': 'Glass drawing board, digital, led screen, drafting technology'}, {'keyword': 'bamboo, innovative, multifunctional'}, {'keyword': 'HVAC-R, hoist motor, lifter, air-conditioning services'}, {'keyword': ' steam, ironing machine, garments'}, {'keyword': 'Engineering, education, technology'}, {'keyword': ' oxy-acetylene, variable frequency drive, pipe welding, pipe rotator, motor'}, {'keyword': 'observation booth, welding, close circuit television, trainer'}, {'keyword': 'spring compressor, hydraulic, electric'}, {'keyword': 'intervention, hedonic motivations, online learning, mobile application'}, {'keyword': 'Module evaluation, flexible learning, modular learning, philippine history, & new normal education'}, {'keyword': 'Support system, transnational families, functionalism theory, Kinship system, patriarchal theory, diaspora'}, {'keyword': 'positive psychology, well-being, mental health, Filipino, grounded theory'}, {'keyword': 'Cultural identity, technical vocation'}, {'keyword': 'Social capital investment, monetary value, non-monetary value, Ifugao cultural community'}, {'keyword': 'Sama Badjao, pregnancy, perinatal beliefs, indigenous'}, {'keyword': 'challenges, Samal Laud, communication, ethnographic'}, {'keyword': 'Sangguniang Kabataan, Katipunan ng Kabataan, youth, governance'}, {'keyword': 'gender, gender education, gender perspectives, exploratory study, SDG, Quezon City University'}, {'keyword': 'Lived experiences, learning management system, online learning, qualitative, phenomenology, Covid-19 p ...

# %%
keywords
# Out:
# ['call center representatives, labor productivity, and employment',
#  'social isolation, work satisfaction, stress, work productivity',
#  'electronic wallet, accuracy of payment, on-time delivery, accessibility and efficiency, security and reliability',
#  'Safety of life at sea program (SOLAS), seafarers, MARITIME accidents, risk reduction management program',
#  'access, faculty portal, features, usability, Universidad de manila',
#  'food safety, sanitation, street food, food handling, consumer',
#  '',
#  'speaking, video recording, oral communication, integration, online learning',
#  'challenges, online learning, Covid-19 pandemic, laboratory teachers, implementation.',
#  'challenges, online learning, Covid-19 pandemic, laboratory',
#  'challenges, online learning, Covid-19 pandemic, laboratory teachers, implementation',
#  'curriculum enhancement, subject understanding, personal qualities, skill, employability',
#  'academic performance, aviation, PhilSCA',
#  'education, course preference, students',
#  "modular distance learning, stakeholders' involvement, remote leaming engagement, parent-teacher partnership",
#  'administrators, blended learning, challenges, opportunities',
#  'research, technology, higher education institution',
#  '',
#  'curriculum design and development, Philippine qualifications framework, hybrid diploma program, developmental research, Philippines',
#  'Tarlac State University, Philippine Ethnolinguistic groups, ethnic stereotypes, national stereotype, national self-stereotype',
#  'higher education institution, practices, resilience, strategic actions',
#  'Engineering, training needs analysis, quantitative, QCU',
#  'thesis repository',
#  'Meta-Leadership Model, sequential-explanatory, crisis leadership competency, pandemic response strategy, crisis management plan',
#  '',
#  'Test of Homogeneity, cabin fever, pandemic, entrepreneurship education, gender differences',
#  'working students, Covid-19, quantitative research, teleworking, employment',
#  'feeding, meat industry, rabbit, rabbit cage, semi-automatic',
#  'supply chain management, logistics, set-based concurrent engineering',
#  'Glass drawing board, digital, led screen, drafting technology',
#  'bamboo, innovative, multifunctional',
#  'HVAC-R, hoist motor, lifter, air-conditioning services',
#  ' steam, ironing machine, garments',
#  'Engineering, education, technology',
#  ' oxy-acetylene, variable frequency drive, pipe welding, pipe rotator, motor',
#  'observation booth, welding, close circuit television, trainer',
#  'spring compressor, hydraulic, electric',
#  'intervention, hedonic motivations, online learning, mobile application',
#  'Module evaluation, flexible learning, modular learning, philippine history, & new normal education',
#  'Support system, transnational families, functionalism theory, Kinship system, patriarchal theory, diaspora',
#  'positive psychology, well-being, mental health, Filipino, grounded theory',
#  'Cultural identity, technical vocation',
#  'Social capital investment, monetary value, non-monetary value, Ifugao cultural community',
#  'Sama Badjao, pregnancy, perinatal beliefs, indigenous',
#  'challenges, Samal Laud, communication, ethnographic',
#  'Sangguniang Kabataan, Katipunan ng Kabataan, youth, governance',
#  'gender, gender education, gender perspectives, exploratory study, SDG, Quezon City University',
#  'Lived experiences, learning management system, online learning, qualitative, phenomenology, Covid-19 pandemic',
#  'organic farming, agricultural practices, information communication materials',
#  '',
#  'Brain drain, Overseas Filipino Workers, employment',
#  'multimedia materials, multimedia demands',
#  'lived experiences, challenges faced during pandemic, coping mechanisms during pandemic',
#  'Degreaser, ethyl-alcohol, laboratory hand tools',
#  'Adjustable, Hydraulic, Notcher, Pipe, Tubular',
#  'urban farming, peasantness, naturalness, adaptation',
#  'Learning motivation, engagement, online class, course structure / organization, learning interactions and activities, classroom settings, students expectations, instructor presence.',
#  'Competency; Employability; Performance; Correlation',
#  'E-commerce, Online Shopping Productivity and availability, Transform Market Place, Technological development and Consumer buying Behavior.',
#  'Mangifera indica; MIL extract; Corrosion Inhibitor',
#  'Automatic transfer switch; Close circuit television; Digital video recorder; Dual power; Trainer',
#  'Repository System, Storage, Thesis',
#  'electronic wallet, accuracy of payment, on-time delivery, accessibility and efficiency, security and reliability',
#  'Home-school; Online Class; Medical Technology education; Covid-19',
#  'Leadership Style, Institutional Sustainability Assessment, Key Results Areas, Development Plan',
#  'Customer satisfaction, service type, safety and security, timing and tracking, pricing, customers feedback.',
#  'Hygroscopic Materials, Atmospheric Water Harvesting, Potability, Photovoltaic Cells,\r\nAdsorption',
#  'Watermelon, Near Infrared Spectroscopy, Maturity, Sugar Level, and Brix\r\nRefractometer',
#  'Local Liquor, Artificial Intelligence (AI), Machine Learning (ML), Electronic Senses,\r\nClassification of Wine',
#  'Drying Chamber, Salinity, Moisture Content, Dried Fish, ATMega328P\r\nMicrocontroller',
#  'Watermelon, Near Infrared Spectroscopy, Maturity, Sugar Level, and Brix\r\nRefractometer',
#  'Automated Egg Incubator, Hatching Rates, ATmega2560, Parameters Optimization,\r\nUrban Husbandry',
#  'LiDROad, Pothole Detector, LiDAR, Severity Classification, GPS Coordinates',
#  'Smart Agriculture, Internet of Things (IoT), Pleurotus Ostreatus, Cultivation,\r\nTechnology',
#  'Power Interruptions, Remote-Controlled Generator, Lithium Phosphate Battery, Two-\r\nway Charging, and Master key',
#  'Urban Farming Food Scarcity Innovative Mobile Application Beneficial and\r\nknowledgeable Helps the environment',
#  'Plastic pollution, Reusability, Biodegradable, Wax wrap, Market research',
#  'Sustainable Development Goals, mosquito repellent; National Tobacco\r\nAdministration; Cigarette Butts; Product Innovation',
#  'Bioplastic, Sustainable, Banana leaf, Eco-friendly, Compostable, Organic',
#  'Can be use for gardening, eco friendly, easy to use, charcoal with Cof ee aroma,\r\ncompacted Biomass',
#  'Flaxseed, Cof ee Grounds, Eco-Gel, Hair Gel, Organic',
#  'Business, Project Feasibility, Multifunctional laptop case, FlexCase Co, Feasibility\r\nAnalysis',
#  'Sustainable candles, Coconut shell scrap charcoal briquettes, Market potential',
#  'Fast growing, aeroponics,Aesthetic, fogger, and tranfer nutrients throughfog',
#  'Automated Yogurt Incubator, ATMEGA328P, Module of Sensors, Streptococcus\r\nThermophilus, Lactobacillus Bulgaricus',
#  'Automatic Mixer, Cocktail Mixer, Automation, Rail Motion Mechanism, Automated\r\nBartender',
#  'Automated Cold Frame, Roofing System, Ventilation System, Microcontroller,\r\nHydroponics',
#  'Brackish Water, Mud Crabs, Recirculating Aquaculture System, Microcontroller-\r\nBased, FIltration',
#  'Mositure, Fertigation, Water, Greenhouse, and ATMega328P',
#  'Fertility Detection, Image Processing, Sorting Scheme, System Automation,\r\nAtmega328P',
#  'iPIPINO, Cucumber,Horticulture, Blynk IoT, NodeMCU ESP82669',
#  'Automation, Microcontrollers, Rabbit, Rabbit Farming, Rabbit Cage',
#  'Urban Farming, Vertical Hydroponics, Artificial Lightings, Climate-Controlled,\r\nInternet of Things (IoT) Technology',
#  'Vermicomposting, African Nightcrawler, Fertilizer, Soil, Automated',
#  'Appetizing, Fresh, Healthy alternative, Rich in fiber, anti-oxidants, Unique',
#  'PVC Plastic, dimmable, organize, wireless, detachable',
#  'Moringa Oleifera, Health-conscious, Complements, Feasible, Sustainability',
#  'Partnership, broomop, 2 - in - 1 product, cleaning materials, convenient',
#  'Cat Litter, Cat ownership, Eco-Friendly, Eco-Cat Litter, Egg tray, Natural,\r\nSustainable, Pandan leaf, Pet supply, Safe Environment',
#  'Sustainable, Compost Fertilizer, Growing Kit, Eco-Friendly, Urban Farming',
#  'Study Space, Convenient, Rental, Top-recommended, Services',
#  'Clipboard, Solar, Light, Partnership, Environmental friendly',
#  'Cof ee Ground Waste, Stoneware Clay, Candle Holder, Luwad ng Hiraya (Clay of\r\nhope)',
#  'Cof ee, Eco-Deodorizer, Odor, Innovative, Refreshener, Feasibility, Brewed',
#  'Automated Quail Monitoring, Microcontroller, Auto Feeding, Auto Disinfectant,\r\nMaintaining Quali`s Temperature',
#  'Advance Farming, Automation system, Rotating hydroponics tower, Leafy crops,\r\nMobile Application (BlynK App)',
#  'Charcoal Collected System, Carbon Monoxide, Black Ink,Smoke Filter, Soot',
#  'Automatomation for Feeding and Watering , Gallus Gallus Domesticus, Blynk Application, Node MCU ESP8266, Internet of Things (IoT)',
#  'San Andreas Strawberry, Cold Frame, Temperature Regulator, GSM Technology, Strawberry Quality System',
#  'ATMega2560, Direct air carbon dioxide capture, Environmental Impact mitigation, Sensor technology, and Sustainable agriculture.',
#  'Banana peel; Banana fiber; Paper Pulp, Kraft paper; Microcontroller',
#  'Fogponics, Indoor Farming, Urban Farming, ATmega328p, Basil',
#  'ATmega2560, Automatic system, Motors, Sensors, DC Battery',
#  'Swine, Automated, Swineherds, and HOGGABLE',
#  'Mini Fridge, Microcontroller Atmega 328P, Temperature, Humidity, Peltier',
#  'Allium Cepa, Onion, Urban Farm, Temperature, NPK (Nitrogen, Phosphorus, and Potassium), Blynk.',
#  'Search and body sensing, ATmega328 Microcontroller, AMG8833, Microphone device, identify and analyse the condition.',
#  'Renewable energy, Wave energy, PiezoElectricity, Energy Harvesting, Scale',
#  'Automation, Dehumidification, Atmospheric, Water Generator, Irrigation System',
#  'Cof ee,Rice,Grains, Instant Cof ee, Health Alternative, Af ordable, Roasted,Drinks, Commercialized,Risk, Healthy,Rice Cof ee, Cafeine, Energy, Muscovado',
#  'Banana Peel, Sustainable, Wrapper, Nutritious, Lumpia',
#  'Bamboo, purity, water filtration system, H20-B Filter, eco',
#  'Multi-functional, study table, students, convenient, multi-modern',
#  'Healthy, Made From Vegetables, Better Taste, Nutritious, Af ordable',
#  '',
#  '',
#  'Green Engineering System, Product Innovation, Food Wrapping, Food Safety, Tremendous Benefits, Improved Life-Cycle Household',
#  'Vegetables, Healthy, Cheese Balls, Innovation, Fusion',
#  'Flavoron, Sweet Potato Polvoron, Ipobaron, Feasibility Study Polvoron, Polvoron',
#  'Antimicrobial Activity, pH level, Sanitizer Spray, Guyabano, Natural Products',
#  'L-shaped, ergonomic factor, four sided, save space, adjustable',
#  'Furniture, Multi-purpose, Ergonomic, Foldable, Comfort',
#  'Hydroponics, Aeroponics, 2-in-1 Solar Powered Agrowtower, Vertical Farming, Limited Partnership',
#  'Tote bag, Eco-friendly, Project Feasibility Study, Business Operations, Laptop Compartment',
#  'Annatto Ink, Cost-Friendly, Environment-Friendly, Partnership, Atsuete',
#  'Sustainable, Eco-friendly, Banana Fiber, Biodegradable and, Desk Lamp',
#  '48 Grams, Cream Dory Fish Fille, District 5 Quezon City, Market Opportunity, Increasing Financial Performance',
#  'Renewable Energy, Solar Energy, Innovation, Revolutionary Technology Market research',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Limited Partnership, banana peel, alternative, floorwax, eco-friendly',
#  'Sole proprietor Banana, Peel, Alternative, Charcoal, Eco-friendly',
#  'Unique snacks, healthier alternative, nutritious, strong demand, positive income',
#  '',
#  'Epoxy-resin, Limited Partnership, Frequency of Agreement, Market Acceptability, Market Share',
#  'Production, Food, Enterprise, Healthy, Cucumber Rolls',
#  'Bitter gourd, spread, nutritious, healthy Spread, cheese spread',
#  'Partnership, pomelo Peel, alternative, charcoal, eco-Friendly',
#  'Eggshells Microbeads, Ef ective cleaner, Innovation, Generate income, Feasible',
#  '',
#  'Door closer,renewable energy, bio-mechanical energy, electrical generating mechanism',
#  'Milkfish and St. Peter’s Fish scale, glossmeter, shoe polish',
#  'Eco-friendly, Decorative Home, styro, plant pot; Recyclable Materials Product',
#  'Cof ee Beans, Feasibility Study, District 3, Caloocan, Cafe',
#  '',
#  'famous cuisines, convenient,af ordable pric, Standard measurements, innovative food product',
#  '',
#  'Dehumidifier, Desiccant, Lemongrass, Natural, and Refresher',
#  'Furniture, Market Demand, Consumer Preferences, Laptop Table Features, Multifunctional Furniture',
#  'Healthy, Alternative, Mung Bean, Unique, Innovative',
#  '',
#  'Service, Solar panel, POBC2, energy-ef icient, charging-station',
#  'Liquid spray, non-sticky, budget friendly, organic soy wax, natural smell',
#  'veggy burger, eggplant, vegetarian, healthy, innovative',
#  'Innovative, Adaptable, Reliable, Comfortability, Helpful',
#  'Portable, Erratic, Accessible, Water-resistant, Anti-glare',
#  'Digital technology, English as a Secondary Language, Chinese education, pedagogy, COVID-19.',
#  'Physical Education, Virtual Learning Environment, Teaching in Virtual Setting, Challenges in Online Learning,',
#  "TOS, Test Item, Grading System, Class Record, Bloom's Taxonomy",
#  "TOS, Test Item, Grading System, Class Record, Bloom's Taxonomy",
#  'following,details, help, manage, submission, system',
#  'sdfs,fdf,d,f,df,d,f',
#  'Cruise Vlogs, Tourist Expectation, Travel Intention, Young Local Tourists, Lyceum of the Philippines University-Manila',
#  'Financial Problem Academic Performance, Part-time Jobs, Absenteeism',
#  'plastic pollution, reuse, biodegradable, wax wrap, market research',
#  ' drying chamber, salinity. moisture content, dried fish, ATMega328P microcontroller ',
#  'brand activism, correlation, brand image, purchase intent,',
#  'distance learning, Quezon City University, COVID-19 Pandemic, laptop distribution, higher education',
#  'distance learning, Quezon City University, COVID-19 Pandemic, laptop distribution, higher education',
#  ' Cruise Vlogs, Tourist Expectation, Travel Intention, Young Local Tourists, Lyceum of the Philippines University-Manila ',
#  'Google Classroom, Learning Management System, Online Class, class, management',
#  'Tourism, Accommodation, Online Review, Airbnb, Booking Intentions',
#  'Malware Detector, Artificial Intelligence,  MATLAB Based System, Al-Based System, MATLAB',
#  'Hotel, Choice, Filipino Tourists, Travel, Tours',
#  ' Hotel Choice, Filipino Tourists, Travel and Tours ',
#  'ssad,d,d,d,d',
#  'Hotel Choice, Filipino Tourists, Travel, Tours.',
#  'Licensure examination, ECE board exam, performance',
#  'Licensure Examination, ECE Board Exam, Performance',
#  'Digital technology, English as a Secondary Language, Chinese education, pedagogy, COVID-19.',
#  ' d,sd,sd, ',
#  'brain injury, brain',
#  'Data Analytics:, Translational Data',
#  'Financial Problem Academic Performance, Part-time Jobs, Absenteeism',
#  '',
#  '',
#  'dsafsf,dsgfgdfgdfgdf,dfdfgdfdggdf',
#  'sdfsdgfsg,dfgfgdfgdfg',
#  '',
#  '',
#  'dsf,dsfsedf',
#  'sddfsdfg,gsfdgdfg']

# %%
extractedKeywords = []
for keys in keywords:
    keys = keys.replace(' ','_').split(',_')
    for key in keys:
        temp = key.lower().strip()
        temp = '_'.join([word for word in temp.split('_') if word not in stop_words])
        temp = ''.join([letter for letter in temp if letter.isalpha() or letter=='_' ])
        if len(temp) != 0:
            key = temp.replace('_',' ') 
            if key.strip() not in extractedKeywords:
                extractedKeywords.append(key)

# %%
extractedKeywords

# %%
with open('extractedKeywords.json', 'w') as file:
    json.dump(extractedKeywords, file)

# %%
# for n, name in enumerate(extractedKeywords):
#     temp = name.lower().split(" ")
#     temp = [''.join([letter for letter in word if letter.isalpha()]) for word in temp]
#     temp = [word for word in temp if word not in stop_words]
#     temp = ' '.join(temp)
#     extractedKeywords[n] = temp
